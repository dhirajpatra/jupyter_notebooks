# %%
import mlflow

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.ensemble import RandomForestRegressor

# %%
mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment("Anomaly Detection")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/846313948183712985', creation_time=1750931452469, experiment_id='846313948183712985', last_update_time=1750931452469, lifecycle_stage='active', name='Anomaly Detection', tags={}>

# %%
mlflow.autolog(log_model_signatures=False, extra_tags={"MY_TAG": "VALUE"})
# Out:
# 2025/06/26 17:31:14 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.

# %%
db = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

# %%
rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)

# %%
# mlflow trigger log automatically
rf.fit(X_train, y_train)
# Out:
# 2025/06/26 17:31:15 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '93a7a9a224194243b6d9813e9a988228', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2025/06/26 17:31:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run gregarious-tern-990 at: http://localhost:5000/#/experiments/846313948183712985/runs/93a7a9a224194243b6d9813e9a988228
# 🧪 View experiment at: http://localhost:5000/#/experiments/846313948183712985
# RandomForestRegressor(max_depth=6, max_features=3)
