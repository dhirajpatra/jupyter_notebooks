# %%
import pandas as pd
import numpy as np

# %%
car=pd.read_csv('car_sales.csv')

# %%
car
# Out:
#     Unnamed: 0 Manufacturer          Model     Type  Min.Price  Price  \
# 0            1        Acura        Integra    Small       12.9   15.9
# 1            2        Acura         Legend  Midsize       29.2   33.9
# 2            3         Audi             90  Compact       25.9   29.1
# 3            4         Audi            100  Midsize       30.8   37.7
# 4            5          BMW           535i  Midsize       23.7   30.0
# 5            6        Buick        Century  Midsize       14.2   15.7
# 6            7        Buick        LeSabre    Large       19.9   20.8
# 7            8        Buick     Roadmaster    Large       22.6   23.7
# 8            9        Buick        Riviera  Midsize       26.3   26.3
# 9           10     Cadillac        DeVille    Large       33.0   34.7
# 10          11     Cadillac        Seville  Midsize       37.5   40.1
# 11          12    Chevrolet       Cavalier  Compact        8.5   13.4
# ...

# %%
car.columns
# Out:
# Index(['Unnamed: 0', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
car.Price.plot.hist()

# %%
car.Price
# Out:
# 0     15.9
# 1     33.9
# 2     29.1
# 3     37.7
# 4     30.0
# 5     15.7
# 6     20.8
# 7     23.7
# 8     26.3
# 9     34.7
# 10    40.1
# 11    13.4
# 12    11.4
# 13    15.1
# 14    15.9
# 15    16.3
# 16    16.6
# 17    18.8
# 18    38.0
# 19    18.4
# 20    15.8
# 21    29.5
# 22     9.2
# 23    11.3
# 24    13.3
# 25    19.0
# 26    15.6
# 27    25.8
# 28    12.2
# 29    19.3
#       ...
# 63    11.8
# 64    15.7
# 65    19.1
# 66    21.5
# 67    13.5
# 68    16.3
# 69    19.5
# 70    20.7
# 71    14.4
# 72     9.0
# 73    11.1
# 74    17.7
# 75    18.5
# 76    24.4
# 77    28.7
# 78    11.1
# 79     8.4
# 80    10.9
# 81    19.5
# 82     8.6
# 83     9.8
# 84    18.4
# 85    18.2
# 86    22.7
# 87     9.1
# 88    19.7
# 89    20.0
# 90    23.3
# 91    22.7
# 92    26.7
# Name: Price, Length: 93, dtype: float64

# %%
np.mean(car.Price)
# Out:
# 19.509677419354837

# %%
np.median(car.Price)
# Out:
# 17.7
