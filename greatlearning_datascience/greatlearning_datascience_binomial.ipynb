# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
n=7
p=.6

# %%
k=np.arange(0,8)
k
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
binomial = stats.binom.pmf(k,n,p)
# probability of [0:?, 1:?, 2:?, 3:?, 4:?, 5:?, 6:?, 7:?]
[(x,y) for x,y in zip(k, binomial)]
# Out:
# [(0, 0.0016384000000000006),
#  (1, 0.01720320000000001),
#  (2, 0.07741440000000002),
#  (3, 0.19353599999999999),
#  (4, 0.29030399999999995),
#  (5, 0.26127360000000005),
#  (6, 0.13063680000000003),
#  (7, 0.027993599999999993)]

# %%
plt.plot(k,binomial,'o-')
plt.title('Binomial: n=%i, p=%.2f' % (n,p), fontsize=15)
plt.xlabel('Number of success')
plt.ylabel('Probability of success')
plt.show()
