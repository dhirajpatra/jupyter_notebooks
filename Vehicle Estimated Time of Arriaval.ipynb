# %%
import numpy as np
import pandas as pd

# %%
AIS = pd.read_csv('~/Downloads/AIS_2019_01_01.csv', delimiter=',')

# %%
AIS.head()
# Out:
#         MMSI         BaseDateTime       LAT        LON  SOG    COG  Heading  \
# 0  338208626  2019-01-01T00:00:05  37.86505 -122.31405  0.0 -165.0    511.0
# 1  367420490  2019-01-01T00:00:04  31.26095  -91.65160  4.5   15.0     31.0
# 2  338060122  2019-01-01T00:00:04  30.67109  -81.46722  1.9  -67.4    511.0
# 3  368018190  2019-01-01T00:00:04  30.70736  -88.04332  0.0 -103.6    301.0
# 4  368039230  2019-01-01T00:00:04  35.08305  -90.14214  0.0 -182.3      4.0
#
#   VesselName  IMO CallSign  VesselType  Status  Length  Width  Draft  Cargo  \
# 0        NaN  NaN      NaN         NaN     0.0     NaN    NaN    NaN    NaN
# 1        NaN  NaN      NaN         NaN    15.0     NaN    NaN    NaN    NaN
# 2        NaN  NaN      NaN         NaN     0.0     NaN    NaN    NaN    NaN
# 3        NaN  NaN      NaN         NaN     0.0     NaN    NaN    NaN    NaN
# 4        NaN  NaN      NaN         NaN     0.0     NaN    NaN    NaN    NaN
#
#   TranscieverClass
# 0                B
# ...

# %%
AIS.tail()
# Out:
#               MMSI         BaseDateTime       LAT        LON   SOG    COG  \
# 7509643  366996830  2019-01-01T23:59:59  38.40355  -82.55581   0.1 -147.3
# 7509644  366947510  2019-01-01T23:59:59  36.84783  -89.14084   4.6   22.0
# 7509645  372945000  2019-01-01T23:59:59  33.66295 -119.43170   8.3   92.0
# 7509646  367567220  2019-01-01T23:59:59  30.02144  -89.90802   0.0 -135.9
# 7509647  367342960  2019-01-01T23:59:59  24.33402  -82.26947  14.7 -145.6
#
#          Heading        VesselName         IMO CallSign  VesselType  Status  \
# 7509643    511.0              ROAN         NaN  WDC2724        31.0     0.0
# 7509644     19.0      INEZ ANDREAS         NaN  WDB7752        31.0    12.0
# 7509645     90.0  ANDROMEDA SPIRIT  IMO9372327    3ELH2        70.0     0.0
# 7509646    180.0        MAN O' WAR         NaN  WDG7432        31.0     0.0
# 7509647    265.0      GOLDEN STATE  IMO9407562     WHDV        80.0     0.0
#
#          Length  Width  Draft  Cargo TranscieverClass
# ...

# %%
AIS[AIS.MMSI==]
