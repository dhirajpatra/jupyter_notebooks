# %%
from sklearn.datasets import load_iris, load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import pandas as pd

# %%
# load and split the data
iris = load_iris()
X = iris.data
y = iris.target

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.75, random_state=42
)

# %%
# define the pipeline
model = Pipeline([
    ("preprocessor", StandardScaler()),
    ("classifier", HistGradientBoostingClassifier(random_state=42))
])

# %%
# define the hyperparameter space
learning_rates = [0.01, 0.1, 1, 10]
max_leaf_nodes = [3, 10, 30]

# %%
best_score = -1
best_params = {}

# %%
# Manual Search
for lr in learning_rates:
    for mln in max_leaf_nodes:
        # Update parameters
        model.set_params(classifier__learning_rate=lr, classifier__max_leaf_nodes=mln)
        
        # Train and score
        model.fit(X_train, y_train)
        score = model.score(X_test, y_test)
        
        if score > best_score:
            best_score = score
            best_params = {'learning-rate': lr, 'max leaf nodes': mln}

# %%
print(f"Best parameters: {best_params}")
print(f"Best score: {best_score}")
# Out:
# Best parameters: {'learning-rate': 0.01, 'max leaf nodes': 3}
# Best score: 1.0

# %%
# support vector classifier
model = SVC()

# %%
# Get the value of the hyperparameter 'degree'
degree_value = model.get_params()['degree']

# %%
print(f"The value of the 'degree' hyperparameter is: {degree_value}")
# Out:
# The value of the 'degree' hyperparameter is: 3

# %%
cancer = load_breast_cancer()

# %%
# features
X = pd.DataFrame(cancer["data"], columns=cancer.feature_names)

# %%
# target label
y = pd.DataFrame(cancer["target"], columns=['Cancer'])

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(
    X, np.ravel(y), test_size=0.3, random_state=42
)

# %%
! pip install scikit-optimize
# Out:
# Requirement already satisfied: scikit-optimize in /home/dhiraj/miniconda3/envs/mlenv/lib/python3.11/site-packages (0.10.2)
# Requirement already satisfied: joblib>=0.11 in /home/dhiraj/miniconda3/envs/mlenv/lib/python3.11/site-packages (from scikit-optimize) (1.5.2)
# Requirement already satisfied: pyaml>=16.9 in /home/dhiraj/miniconda3/envs/mlenv/lib/python3.11/site-packages (from scikit-optimize) (25.7.0)
# Requirement already satisfied: numpy>=1.20.3 in /home/dhiraj/miniconda3/envs/mlenv/lib/python3.11/site-packages (from scikit-optimize) (2.4.0)
# Requirement already satisfied: scipy>=1.1.0 in /home/dhiraj/miniconda3/envs/mlenv/lib/python3.11/site-packages (from scikit-optimize) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /home/dhiraj/miniconda3/envs/mlenv/lib/python3.11/site-packages (from scikit-optimize) (1.8.0)
# Requirement already satisfied: packaging>=21.3 in /home/dhiraj/miniconda3/envs/mlenv/lib/python3.11/site-packages (from scikit-optimize) (25.0)
# Requirement already satisfied: PyYAML in /home/dhiraj/miniconda3/envs/mlenv/lib/python3.11/site-packages (from pyaml>=16.9->scikit-optimize) (6.0.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/dhiraj/miniconda3/envs/mlenv/lib/python3.11/site-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.6.0)

# %%
from skopt import BayesSearchCV
# parameter ranges 
from skopt.space import Real, Categorical, Integer

# %%
# Define search space
search_space = {
    'C': Real(0.1, 1e+4, prior='uniform'),
    'gamma': Real(1e-6, 1e+1, prior='log-uniform')
}

# %%
# Initialize BayesSearchCV
bayes_search = BayesSearchCV(
    SVC(),
    search_space,
    n_iter=20,
    cv=5,
    random_state=42,
    verbose=3
)

# %%
# Fit model
bayes_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=4101.098578137254, gamma=0.1241881627783703;, score=0.625 total time=   0.0s
# [CV 2/5] END C=4101.098578137254, gamma=0.1241881627783703;, score=0.625 total time=   0.0s
# [CV 3/5] END C=4101.098578137254, gamma=0.1241881627783703;, score=0.625 total time=   0.0s
# [CV 4/5] END C=4101.098578137254, gamma=0.1241881627783703;, score=0.633 total time=   0.0s
# [CV 5/5] END C=4101.098578137254, gamma=0.1241881627783703;, score=0.620 total time=   0.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C
total time=   0.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=10000.0, gamma=8.91500467680388e-06;, score=0.963 total time=   0.0s
# [CV 2/5] END C=10000.0, gamma=8.91500467680388e-06;, score=0.912 total time=   0.0s
# [CV 3/5] END C=10000.0, gamma=8.91500467680388e-06;, score=0.963 total time=   0.0s
# [CV 4/5] END C=10000.0, gamma=8.91500467680388e-06;, score=0.911 total time=   0.0s
# [CV 5/5] END C=10000.0, gamma=8.91500467680388e-06;, score=0.924 total time=   0.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=0.1, gamma=1.6439464301648306e-06;, score=0.900 total time=   0.0s
# [CV 2/5] END C=0.1, gamma=1.6439464301648306e-06;, score=0.900 total time=   0.0s
# [CV 3/5] END C=0.1, gamma=1.6439464301648306e-06;, score=0.938 total time=   0.0s
# [CV 4/5] END C=0.1, gamma=1.6439464301648306e-06;, score=0.835 total time=   0.0s
# [CV 5/5] END C=0.1, gamma=1.6439464301648306e-06;, score=0.873 total time=   0.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=10000.0, gamma=2.0825279488816488e-05;, score=0.950 total time=   0.0s
# [CV 2/5] END C=10000.0, gamma=2.0825279488816488e-05;, score=0.925 total time=   0.0s
# [CV 3/5] END C=10000.0, gamma=2.0825279488816488e-05;, score=0.938 total time=   0.0s
# [CV 4/5] END C=10000.0, gamma=2.0825279488816488e-05;, score=0.899 total time=   0.0s
# [CV 5/5] END C=10000.0, gamma=2.0825279488816488e-05;, score=0.924 total time=   0.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ............C=10000.0, gamma=1e-06;, score=0.950 total time=   0.0s
# [CV 2/5] END ............C=10000.0, gamma=1e-06;, score=0.938 total time=   0.0s
# [CV 3/5] END ............C=10000.0, gamma=1e-06;, score=0.950 total time=   0.0s
# [CV 4/5] END ............C=10000.0, gamma=1e-06;, score=0.937 total time=   0.0s
# [CV 5/5] END ............C=10000.0, gamma=1e-06;, score=0.911 total time=   0.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=10000.0, gamma=8.415243475791306e-06;, score=0.963 total time=   0.0s
# [CV 2/5] END C=10000.0, gamma=8.415243475791306e-06;, score=0.912 total time=   0.0s
# [CV 3/5] END C=10000.0, gamma=8.415243475791306e-06;, score=0.963 total time=   0.0s
# [CV 4/5] END C=10000.0, gamma=8.415243475791306e-06;, score=0.899 total time=   0.0s
# [CV 5/5] END C=10000.0, gamma=8.415243475791306e-06;, score=0.937 total time=   0.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=0.1, gamma=5.050991857952524e-06;, score=0.900 total time=   0.0s
# [CV 2/5] END C=0.1, gamma=5.050991857952524e-06;, score=0.900 total time=   0.0s
# [CV 3/5] END C=0.1, gamma=5.050991857952524e-06;, score=0.963 total time=   0.0s
# [CV 4/5] END C=0.1, gamma=5.050991857952524e-06;, score=0.861 total time=   0.0s
# [CV 5/5] END C=0.1, gamma=5.050991857952524e-06;, score=0.861 total time=   0.0s
# BayesSearchCV(cv=5, estimator=SVC(), n_iter=20, random_state=42,
#               search_spaces={'C': Real(low=0.1, high=10000.0, prior='uniform', transform='normalize'),
#                              'gamma': Real(low=1e-06, high=10.0, prior='log-uniform', transform='normalize')},
#               verbose=3)

# %%
# Predict and evaluate
y_pred = bayes_search.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95        63
#            1       0.96      0.98      0.97       108
#
#     accuracy                           0.96       171
#    macro avg       0.97      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %%
# load and split the data
iris = load_iris()
X = iris.data
y = iris.target

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.76, random_state=42
)

# %%
# Show the number of rows in the training data
print(len(X_train))
# Out:
# 114
