# %% [markdown]
# # Q1. What is Pandas?

# %% [markdown]
# pandas is an open source library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.

# %% [markdown]
# ```
# ! pip install pandas
# ```

# %%
# conventional way to import pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Q2. What kind of data does pandas handle?

# %% [markdown]
# When working with tabular data, such as data stored in spreadsheets or databases, pandas is the right tool for you. pandas will help you to explore, clean, and process your data. In pandas, a data table is called a `DataFrame`.
#
# ![image.png](data:image/png;base64,...)
#
# A DataFrame is a 2-dimensional data structure that can store data of different types (including characters, integers, floating point values, categorical data and more) in columns. It is similar to a spreadsheet, a SQL table or the `data.frame` in R.

# %%
arr = np.array([1,2,3])
arr.dtype
# Out:
# dtype('int64')

# %%
df = pd.DataFrame(
     {
         "Name": [
             "Braund, Mr. Owen Harris",
             "Allen, Mr. William Henry",
             "Bonnell, Miss. Elizabeth",
         ],
         "Age": [22, 35, 58],
         "Sex": ["male", "male", "female"]
     }
 )


df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
df.dtypes # str is a subclass of object data type
# Out:
# Name      str
# Age     int64
# Sex       str
# dtype: object

# %% [markdown]
# * The table has 3 columns, each of them with a column label. The column labels are respectively Name, Age and Sex.
#
# * The column Name consists of textual data with each value a string, the column Age are numbers and the column Sex is textual data.

# %% [markdown]
# # Q3. What is pandas Series?
#
# Each column in a DataFrame is a Series.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When selecting a single column of a pandas DataFrame, the result is a pandas Series. To select the column, use the column label in between square brackets [].

# %%
df["Age"]
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
type(df["Age"])
# Out:
# pandas.Series

# %% [markdown]
# You can create a Series from scratch as well:

# %%
ages = pd.Series([22, 35, 58], name="Age")

# %%
ages
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %% [markdown]
# A pandas Series has no column labels, as it is just a single column of a DataFrame. A Series does have row labels.

# %% [markdown]
# # Q4: How do I read and write tabular data?

# %% [markdown]
# * CSV
# * XLSX
# * JSON
# * PARQUET
# * AVRO
# * SQL
# * XML
# * HDF5
# * GBQ
# * TSV

# %% [markdown]
# pandas supports the integration with many file formats or data sources out of the box (csv, excel, sql, json, parquet,…). Importing data from each of these data sources is provided by function with the prefix read_*. Similarly, the to_* methods are used to store data.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# pandas provides the `read_csv()` function to read data stored as a csv file into a pandas DataFrame.

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# @title Embarked

from matplotlib import pyplot as plt
import seaborn as sns
titanic.groupby('Embarked').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
titanic.to_excel("titanic.xlsx", sheet_name="passengers", index=False)

# %% [markdown]
# # Q5: How can I see the first few rows of a dataframe?

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %% [markdown]
# # Q6: How can I see the last few rows of a dataframe?

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.tail(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# ...

# %% [markdown]
# # Q7: How can I get the data types of each column in a dataframe?

# %%
type(titanic)
# Out:
# pandas.DataFrame

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
titanic['Age'].dtype
# Out:
# dtype('float64')

# %%
titanic['Age'].astype('object')
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: object

# %%
titanic['Age'].dtype
# Out:
# dtype('float64')

# %%
# How do I change the data type of a column
titanic["PassengerId"] = titanic["PassengerId"].astype(object)

# %%
titanic.dtypes
# Out:
# PassengerId     object
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %% [markdown]
# # Q8: How do I select a subset of the dataframe?

# %% [markdown]
# Selecting or filtering specific rows and/or columns? Filtering the data on a condition? Methods for slicing, selecting, and extracting the data you need are available in pandas.
# ![image.png](data:image/png;base64,...)

# %%
# To select a single column, use square brackets [] with the column name of the column of interest.
ages = titanic["Age"]
ages.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
type(titanic["Age"])
# Out:
# pandas.Series

# %%
print(type(titanic["Age"]))
print(type(titanic[["Age"]]))
# Out:
# <class 'pandas.Series'>
# <class 'pandas.DataFrame'>

# %%
titanic["Age"].shape
# Out:
# (891,)

# %%
titanic[["Age"]].shape
# Out:
# (891, 1)

# %%
type(titanic["Age"])
# Out:
# pandas.Series

# %%
type(titanic[["Age"]])
# Out:
# pandas.DataFrame

# %% [markdown]
# To select multiple columns, use a list of column names within the selection brackets [].

# %%
age_sex = titanic[["Age", "Sex"]]

# %%
age_sex.head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
type(titanic[["Age", "Sex"]])
# Out:
# pandas.DataFrame

# %%
type(age_sex)
# Out:
# pandas.DataFrame

# %%
titanic[["Age", "Sex"]].shape
# Out:
# (891, 2)

# %%
# SAME AS ABOVE CELL
sel_cols = ["Age", "Sex"]
titanic[sel_cols].shape
# Out:
# (891, 2)

# %% [markdown]
# # Q9: How do I filter specific rows from a DataFrame?

# %% [markdown]
# To select rows based on a conditional expression, use a condition inside the selection brackets [].

# %%
titanic["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(titanic["Age"])
# Out:
# pandas.Series

# %%
# It will return only boolean result
titanic["Age"] >= 35
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
titanic[titanic["Age"] >= 35]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 4             5         0       3
# 6             7         0       1
# 11           12         1       1
# ..          ...       ...     ...
# 865         866         1       2
# 871         872         1       1
# 873         874         0       3
# 879         880         1       1
# 885         886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(titanic["Age"] > 35)
# Out:
# pandas.Series

# %%
above_35 = titanic[titanic["Age"] > 35]

# %%
above_35.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 6            7         0       1
# 11          12         1       1
# 13          14         0       3
# 15          16         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 13      5    347082  31.2750   NaN        S
# 15      0    248706  16.0000   NaN        S

# %%
above_35.shape
# Out:
# (217, 12)

# %%
titanic["Pclass"].isin([2,3])
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Pclass, Length: 891, dtype: bool

# %%
class_23 = titanic[titanic["Pclass"].isin([2, 3])]

# %%
class_23.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 4            5         0       3
# 5            6         0       3
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
# 10          11         1       3
# 12          13         0       3
# 13          14         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %%
class_23.shape
# Out:
# (675, 12)

# %%
above_35_class_23 = titanic[(titanic["Pclass"].isin([2,3])) & (titanic["Age"] > 35)]

# %%
above_35_class_23.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 13          14         0       3
# 15          16         1       2
# 25          26         1       3
# 33          34         0       2
# 40          41         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 33                              Wheadon, Mr. Edward H    male  66.0      0
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
#
#     Parch      Ticket     Fare Cabin Embarked
# 13      5      347082  31.2750   NaN        S
# 15      0      248706  16.0000   NaN        S
# 25      5      347077  31.3875   NaN        S
# 33      0  C.A. 24579  10.5000   NaN        S
# 40      0        7546   9.4750   NaN        S

# %%
age_cond = titanic["Age"]> 35
age_cond.name = "age_condition"
pd.concat([titanic["Age"],age_cond], axis = 1)
# Out:
#       Age  age_condition
# 0    22.0          False
# 1    38.0           True
# 2    26.0          False
# 3    35.0          False
# 4    35.0          False
# ..    ...            ...
# 886  27.0          False
# 887  19.0          False
# 888   NaN          False
# 889  26.0          False
# 890  32.0          False
#
# [891 rows x 2 columns]

# %%
pclass_cond = titanic["Pclass"].isin([2, 3])
pclass_cond.name = "pclass_condition"
pd.concat([pd.concat([titanic["Pclass"],pclass_cond], axis = 1), pd.concat([titanic["Age"],age_cond], axis = 1)], axis = 1)
# Out:
#      Pclass  pclass_condition   Age  age_condition
# 0         3              True  22.0          False
# 1         1             False  38.0           True
# 2         3              True  26.0          False
# 3         1             False  35.0          False
# 4         3              True  35.0          False
# ..      ...               ...   ...            ...
# 886       2              True  27.0          False
# 887       1             False  19.0          False
# 888       3              True   NaN          False
# 889       1             False  26.0          False
# 890       3              True  32.0          False
#
# [891 rows x 4 columns]

# %%
above_35_class_23 = titanic[(titanic["Pclass"].isin([2, 3])) & (titanic["Age"] > 35)]

# %%
above_35_class_23.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 13          14         0       3
# 15          16         1       2
# 25          26         1       3
# 33          34         0       2
# 40          41         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 33                              Wheadon, Mr. Edward H    male  66.0      0
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
#
#     Parch      Ticket     Fare Cabin Embarked
# 13      5      347082  31.2750   NaN        S
# 15      0      248706  16.0000   NaN        S
# 25      5      347077  31.3875   NaN        S
# 33      0  C.A. 24579  10.5000   NaN        S
# 40      0        7546   9.4750   NaN        S

# %%
above_35_class_23.shape
# Out:
# (113, 12)

# %%
titanic["Age"].notna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
age_no_na = titanic[titanic["Age"].notna()]

# %%
age_no_na.head()
# Out:
#   PassengerId  Survived  Pclass  \
# 0           1         0       3
# 1           2         1       1
# 2           3         1       3
# 3           4         1       1
# 4           5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
age_no_na.shape
# Out:
# (714, 12)

# %% [markdown]
# # Q10: How do I select specific rows and columns from a DataFrame?

# %%
titanic[titanic["Age"] > 18][["Name", "Pclass", "Age"]]
# Out:
#                                                   Name  Pclass   Age
# 0                              Braund, Mr. Owen Harris       3  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  38.0
# 2                               Heikkinen, Miss. Laina       3  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  35.0
# 4                             Allen, Mr. William Henry       3  35.0
# ..                                                 ...     ...   ...
# 885               Rice, Mrs. William (Margaret Norton)       3  39.0
# 886                              Montvila, Rev. Juozas       2  27.0
# 887                       Graham, Miss. Margaret Edith       1  19.0
# 889                              Behr, Mr. Karl Howell       1  26.0
# 890                                Dooley, Mr. Patrick       3  32.0
#
# [575 rows x 3 columns]

# %%
titanic.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
titanic.loc

# %%
# BETTER WAY - MORE EFFICIENT
adult_names_cond = titanic.loc[titanic["Age"] > 18, [len(x) < 5 for x in titanic.columns.tolist()]]

# %%
# BETTER WAY - MORE EFFICIENT
adult_names_list = titanic.loc[titanic["Age"] > 18, ["Name", "Age", "Fare"]]

# %%
adult_names_cond.head()
# Out:
#                                                 Name     Sex   Age     Fare
# 0                            Braund, Mr. Owen Harris    male  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                           Allen, Mr. William Henry    male  35.0   8.0500

# %%
adult_names_list.head()
# Out:
#                                                 Name   Age     Fare
# 0                            Braund, Mr. Owen Harris  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  53.1000
# 4                           Allen, Mr. William Henry  35.0   8.0500

# %% [markdown]
# # Q11: What are the `loc` and `iloc` operators?

# %% [markdown]
# In this case, a subset of both rows and columns is made in one go and just using selection brackets [] is not sufficient anymore. The loc/iloc operators are required in front of the selection brackets []. When using loc/iloc, the part before the comma is the rows you want, and the part after the comma is the columns you want to select.

# %%
titanic.iloc[9:28, 2:5] # inclusive start : exclusive end
# Out:
#     Pclass                                               Name     Sex
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3                    Sandstrom, Miss. Marguerite Rut  female
# 11       1                           Bonnell, Miss. Elizabeth  female
# 12       3                     Saundercock, Mr. William Henry    male
# 13       3                        Andersson, Mr. Anders Johan    male
# 14       3               Vestrom, Miss. Hulda Amanda Adolfina  female
# 15       2                   Hewlett, Mrs. (Mary D Kingcome)   female
# 16       3                               Rice, Master. Eugene    male
# 17       2                       Williams, Mr. Charles Eugene    male
# 18       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 19       3                            Masselmani, Mrs. Fatima  female
# 20       2                               Fynney, Mr. Joseph J    male
# ...

# %%
titanic.iloc[0:3, 3] = "anonymous"
titanic.head()
# Out:
#   PassengerId  Survived  Pclass                                          Name  \
# 0           1         0       3                                     anonymous
# 1           2         1       1                                     anonymous
# 2           3         1       3                                     anonymous
# 3           4         1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           5         0       3                      Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# # Q12: How do I create plots in pandas?
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
help(pd.DataFrame.plot)
# Out:
# Help on class PlotAccessor in module pandas.plotting:
#
# class PlotAccessor(pandas.core.base.PandasObject)
#  |  PlotAccessor(data: 'Series | DataFrame') -> 'None'
#  |
#  |  Make plots of Series or DataFrame.
#  |
#  |  Uses the backend specified by the
#  |  option ``plotting.backend``. By default, matplotlib is used.
#  |
#  |  Parameters
#  |  ----------
#  |  data : Series or DataFrame
#  |      The object for which the method is called.
#  |
#  |  Attributes
#  |  ----------
#  |  x : label or position, default None
#  |      Only used if data is a DataFrame.
#  |  y : label, position or list of label, positions, default None
#  |      Allows plotting of one column versus another. Only used if data is a
#  |      DataFrame.
#  |  kind : str
#  |      The kind of plot to produce:
#  |
#  |      - 'line' : line plot (default)
#  |      - 'bar' : vertical bar plot
#  |      - 'barh' : horizontal bar plot
#  |      - 'hist' : histogram
#  |      - 'box' : boxplot
# ...

# %%
air_quality = pd.read_csv(
    "~/Downloads/air-quality-data-set/AirQuality.csv",
    sep=";",
    decimal=","
)

print(air_quality.columns)
print(air_quality.head())
print(air_quality.shape)
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='str')
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# ...

# %%
air_quality.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %%
air_quality.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='str')

# %%
# Remove useless columns
air_quality = air_quality.drop(columns=["Unnamed: 15", "Unnamed: 16"])

# Convert dataset's missing-value marker to NaN
air_quality = air_quality.replace(-200, pd.NA)

# Convert all columns except 'Date' and 'Time' to numeric  
for col in air_quality.columns:  
    if col not in ['Date', 'Time']:  
        air_quality[col] = pd.to_numeric(air_quality[col], errors='coerce')  
  
# Interpolate only numeric columns  
air_quality[air_quality.columns.difference(['Date', 'Time'])] = air_quality[air_quality.columns.difference(['Date', 'Time'])].interpolate()  
  
print(air_quality.head())  

# Check
print(air_quality.isna().sum())
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
air_quality.plot()
# Out:
# <Axes: >

# %%
# air_quality["station_paris"].plot()

# %%
# air_quality.plot.scatter(x="station_london", y="station_paris", alpha=0.5, color="red");

# %%
air_quality.plot.box()
# Out:
# <Axes: >

# %%
axs = air_quality.plot.area(figsize=(12, 4), subplots=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 axs = air_quality.plot.area(figsize=(12, 4), subplots=True)
#       2 plt.show()
#
# File ~/miniconda3/envs/gpu-torch/lib/python3.11/site-packages/pandas/plotting/_core.py:1901, in PlotAccessor.area(self, x, y, stacked, **kwargs)
#    1818 def area(
#    1819     self,
#    1820     x: Hashable | None = None,
#    (...)   1823     **kwargs,
#    1824 ) -> PlotAccessor:
#    1825     """
#    1826     Draw a stacked area plot.
#    1827
#    (...)   1899         >>> ax = df.plot.area(x="day")
#    1900     """
# -> 1901     return self(kind="area", x=x, y=y, stacked=stacked, **kwargs)
#
# File ~/miniconda3/envs/gpu-torch/lib/python3.11/site-packages/pandas/plotting/_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
# ...

# %% [markdown]
# # Q13: How to create new columns derived from existing columns?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To create a new column, use the [] brackets with the new column name at the left side of the assignment.

# %%
# air_quality["london_mg_per_cubic"] = air_quality["station_london"] * 1.882
# air_quality.head()

# %%
# air_quality["ratio_paris_antwerp"] = (air_quality["station_paris"] / air_quality["station_antwerp"])
# air_quality.head()

# %% [markdown]
# # Q14: How can I rename the columns?

# %%
air_quality_renamed = air_quality.rename(
    columns={
        "CO(GT)": "Carbon Monoxide",
        "C6H6(GT)": "Benzene",
    }
)
air_quality_renamed.head()
# Out:
#          Date      Time  Carbon Monoxide  PT08.S1(CO)  NMHC(GT)  Benzene  \
# 0  10/03/2004  18.00.00              2.6       1360.0     150.0     11.9
# 1  10/03/2004  19.00.00              2.0       1292.0     112.0      9.4
# 2  10/03/2004  20.00.00              2.2       1402.0      88.0      9.0
# 3  10/03/2004  21.00.00              2.2       1376.0      80.0      9.2
# 4  10/03/2004  22.00.00              1.6       1272.0      51.0      6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# ...

# %%
air_quality_renamed = air_quality_renamed.rename(columns=str.lower)

air_quality_renamed.head()
# Out:
#          date      time  carbon monoxide  pt08.s1(co)  nmhc(gt)  benzene  \
# 0  10/03/2004  18.00.00              2.6       1360.0     150.0     11.9
# 1  10/03/2004  19.00.00              2.0       1292.0     112.0      9.4
# 2  10/03/2004  20.00.00              2.2       1402.0      88.0      9.0
# 3  10/03/2004  21.00.00              2.2       1376.0      80.0      9.2
# 4  10/03/2004  22.00.00              1.6       1272.0      51.0      6.5
#
#    pt08.s2(nmhc)  nox(gt)  pt08.s3(nox)  no2(gt)  pt08.s4(no2)  pt08.s5(o3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       t    rh      ah
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# ...

# %% [markdown]
# # Q15: How to calculate summary statistics?
#
# ![image.png](data:image/png;base64,...)

# %%
titanic["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
titanic[["Age", "Fare"]].median()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
titanic[["Age", "Fare"]].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
titanic.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# Instead of the predefined statistics, specific combinations of aggregating summary statistics for given columns can be defined using the DataFrame.agg() method.

# %%
titanic.agg(
    {
        "Age": ["min", "max", "median", "skew"],
        "Fare": ["min", "max", "median", "mean"],
    }
)
# Out:
#               Age        Fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# median  28.000000   14.454200
# skew     0.389108         NaN
# mean          NaN   32.204208

# %% [markdown]
# # Q16: How can I aggregate by groups?
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Calculating a given statistic (e.g. mean age) for each category in a column (e.g. male/female in the Sex column) is a common pattern. The groupby method is used to support this type of operations. This fits in the more general split-apply-combine pattern:
#
# * Split the data into groups
#
# * Apply a function to each group independently
#
# * Combine the results into a data frame

# %%
titanic[["Sex", "Age"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
titanic.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
titanic.groupby(["Sex", "Pclass"])["Fare"].mean()

# %% [markdown]
# # Q17: How can I count number of records by category?
#
# ![image.png](data:image/png;base64,...)

# %%
titanic["Pclass"].value_counts()

# %% [markdown]
# # Q18: How to concatenate two tables?
#
# ![image.png](data:image/png;base64,...)

# %%
air_quality_no2 = pd.read_csv("/content/drive/MyDrive/GFG/56. Pandas Deepdive - 19th May, 2024/data/air_quality_no2_long.csv", parse_dates=True)

# %%
air_quality_no2 = air_quality_no2[["date.utc", "location", "parameter", "value"]]

# %%
air_quality_pm25 = pd.read_csv("/content/drive/MyDrive/GFG/56. Pandas Deepdive - 19th May, 2024/data/air_quality_pm25_long.csv", parse_dates=True)

# %%
air_quality_pm25 = air_quality_pm25[["date.utc", "location", "parameter", "value"]]

# %%
air_quality_no2.head()

# %%
air_quality_pm25.head()

# %%
air_quality = pd.concat([air_quality_pm25, air_quality_no2], axis=0) # axis = rows
air_quality.head()

# %%
air_quality.tail()

# %% [markdown]
# The concat() function performs concatenation operations of multiple tables along one of the axes (row-wise or column-wise).

# %%
print('Shape of the ``air_quality_pm25`` table: ', air_quality_pm25.shape)
print('Shape of the ``air_quality_no2`` table: ', air_quality_no2.shape)
print('Shape of the resulting ``air_quality`` table: ', air_quality.shape)

# %% [markdown]
# # Q19: How can I sort data frame by column(s)?

# %%
air_quality = air_quality.sort_values("date.utc")
air_quality.head()

# %% [markdown]
# # Q20: How can I join tables using a common identifier?
#
# ![image.png](data:image/png;base64,...)

# %%
stations_coord = pd.read_csv("/content/drive/MyDrive/GFG/56. Pandas Deepdive - 19th May, 2024/data/air_quality_stations.csv")
stations_coord.head()

# %%
air_quality.head()

# %%
air_quality = pd.merge(air_quality, stations_coord, how="left", on="location")
air_quality.head()

# %%
air_quality_parameters = pd.read_csv("/content/drive/MyDrive/GFG/56. Pandas Deepdive - 19th May, 2024/data/air_quality_parameters.csv")
air_quality_parameters.head()

# %%
air_quality = pd.merge(air_quality, air_quality_parameters, how='left', left_on='parameter', right_on='id')
air_quality.head()

# %% [markdown]
# # Q21: How can I handle time series data?

# %%
air_quality = pd.read_csv("/content/drive/MyDrive/GFG/56. Pandas Deepdive - 19th May, 2024/data/air_quality_no2_long.csv")
air_quality = air_quality.rename(columns={"date.utc": "datetime"})
air_quality.head()

# %%
air_quality.city.unique()

# %%
air_quality["datetime"] = pd.to_datetime(air_quality["datetime"])

# %% [markdown]
# Initially, the values in datetime are character strings and do not provide any datetime operations (e.g. extract the year, day of the week,…). By applying the to_datetime function, pandas interprets the strings and convert these to datetime (i.e. datetime64[ns, UTC]) objects. In pandas we call these datetime objects similar to datetime.datetime from the standard library as pandas.Timestamp.

# %%
air_quality["datetime"].min(), air_quality["datetime"].max()

# %%
air_quality["datetime"].max() - air_quality["datetime"].min()

# %%
air_quality["month"] = air_quality["datetime"].dt.month
air_quality.head()

# %%
air_quality.groupby([air_quality["datetime"].dt.weekday, "location"])["value"].mean()

# %%
fig, axs = plt.subplots(figsize=(12, 4))

air_quality.groupby(air_quality["datetime"].dt.hour)["value"].mean().plot(
    kind='bar', rot=0, ax=axs
)

plt.xlabel("Hour of the day");
plt.ylabel("$NO_2 (µg/m^3)$");

# %% [markdown]
# # Q22: How can I pivot the table by date?

# %%
no_2 = air_quality.pivot(index="datetime", columns="location", values="value")

# %%
no_2.head()

# %%
no_2.index.year, no_2.index.weekday

# %%
no_2["2019-05-20":"2019-05-21"].plot();

# %% [markdown]
# # Q23: How can I manipulate textual data in dataframe?

# %%
titanic = pd.read_csv("/content/drive/MyDrive/GFG/56. Pandas Deepdive - 19th May, 2024/data/titanic.csv")
titanic.head()

# %%
titanic["Name"].str.lower()

# %%
titanic["Name"].str.split(",")

# %%
titanic["Surname"] = titanic["Name"].str.split(",").str.get(0)
titanic["Surname"]

# %%
# Extract the passenger data about the countesses on board of the Titanic.

titanic["Name"].str.contains("Countess")

# %%
titanic[titanic["Name"].str.contains("Countess")]

# %%
# Which passenger of the Titanic has the longest name?

titanic["Name"].str.len()

# %%
titanic["Name"].str.len().idxmax()

# %%
titanic.loc[titanic["Name"].str.len().idxmax(), "Name"]

# %%
titanic["Sex_short"] = titanic["Sex"].replace({"male": "M", "female": "F"})
