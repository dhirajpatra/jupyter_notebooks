# %%
from keras.preprocessing.image import ImageDataGenerator
from keras import layers, models, callbacks
from keras.utils import load_img, img_to_array
from keras.optimizers import RMSprop
import os
import numpy as np
import matplotlib.pyplot as plt
import keras
import random
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.11.0

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images"
# Out:
# ls: cannot access '/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images': No such file or directory

# %%
FAST_RUN = False
IMAGE_WIDTH=256
IMAGE_HEIGHT=256
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3
BATCH_SIZE = 32

# %%
# Set the directory for the training images
test_dir = '/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/test'
validation_dir = '/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate'

# %%
class_dict = {0: "snow", 1: "no_snow"}

# %%
# Load the saved model
loaded_model = models.load_model('gdrive/MyDrive/models/snow_detection_model.h5')

# %%
# from keras.preprocessing.image import load_img, img_to_array
from keras.utils import load_img, img_to_array
import numpy as np

img_path = "/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/snow/Copy of Copy of bfd7f1d666fd3430f9bb513dd3ae5acd.jpg"

# Load and preprocess your image
img = load_img(img_path, target_size=(256, 256))
# img = load_img(img_path, target_size=(128, 128))
# Show image
plt.imshow(img)
plt.show()

img = img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img/255.0

# Make a prediction
prediction = loaded_model.predict(img)

# Get the predicted class
predicted_class = np.argmax(prediction, axis=1)

print("")
print(class_dict[predicted_class[0]])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-99dacda0dfe8> in <module>
#       6
#       7 # Load and preprocess your image
# ----> 8 img = load_img(img_path, target_size=(256, 256))
#       9 # img = load_img(img_path, target_size=(128, 128))
#      10 # Show image
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420         if isinstance(path, pathlib.Path):
#     421             path = str(path.resolve())
# --> 422         with open(path, "rb") as f:
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/snow/Copy of Copy of bfd7f1d666fd3430f9bb513dd3ae5acd.jpg'

# %%
# from keras.preprocessing.image import load_img, img_to_array
from keras.utils import load_img, img_to_array
import numpy as np

img_path = "/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/snow/Copy of 4209417545_ee945518e5.jpg"

# Load and preprocess your image
img = load_img(img_path, target_size=(256, 256))
# img = load_img(img_path, target_size=(128, 128))
# Show image
plt.imshow(img)
plt.show()

img = img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img/255.0

# Make a prediction
prediction = loaded_model.predict(img)

# Get the predicted class
predicted_class = np.argmax(prediction, axis=1)

print("")
print(class_dict[predicted_class[0]])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-ca951fcd1a05> in <module>
#       6
#       7 # Load and preprocess your image
# ----> 8 img = load_img(img_path, target_size=(256, 256))
#       9 # img = load_img(img_path, target_size=(128, 128))
#      10 # Show image
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420         if isinstance(path, pathlib.Path):
#     421             path = str(path.resolve())
# --> 422         with open(path, "rb") as f:
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/snow/Copy of 4209417545_ee945518e5.jpg'

# %%
# from keras.preprocessing.image import load_img, img_to_array
from keras.utils import load_img, img_to_array
import numpy as np

img_path = "/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/snow/Copy of 4209417545_ee945518e5.jpg"

# Load and preprocess your image
img = load_img(img_path, target_size=(256, 256))
# img = load_img(img_path, target_size=(128, 128))
# Show image
plt.imshow(img)
plt.show()

img = img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img/255.0

# Make a prediction
prediction = loaded_model.predict(img)

# Get the predicted class
predicted_class = np.argmax(prediction, axis=1)

print("")
print(class_dict[predicted_class[0]])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-ca951fcd1a05> in <module>
#       6
#       7 # Load and preprocess your image
# ----> 8 img = load_img(img_path, target_size=(256, 256))
#       9 # img = load_img(img_path, target_size=(128, 128))
#      10 # Show image
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420         if isinstance(path, pathlib.Path):
#     421             path = str(path.resolve())
# --> 422         with open(path, "rb") as f:
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/snow/Copy of 4209417545_ee945518e5.jpg'

# %%
# from keras.preprocessing.image import load_img, img_to_array
from keras.utils import load_img, img_to_array
import numpy as np

img_path = "/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/snow/Copy of Copy of Copy of solar-panel-field-covered-snow-renewable-energy-winter-low-efficiency-renewable-green-energy-industry-concept-winter-211431345.jpg"

# Load and preprocess your image
img = load_img(img_path, target_size=(256, 256))
# img = load_img(img_path, target_size=(128, 128))
# Show image
plt.imshow(img)
plt.show()

img = img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img/255.0

# Make a prediction
prediction = loaded_model.predict(img)

# Get the predicted class
predicted_class = np.argmax(prediction, axis=1)

print("")
print(class_dict[predicted_class[0]])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-0726384df103> in <module>
#       6
#       7 # Load and preprocess your image
# ----> 8 img = load_img(img_path, target_size=(256, 256))
#       9 # img = load_img(img_path, target_size=(128, 128))
#      10 # Show image
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420         if isinstance(path, pathlib.Path):
#     421             path = str(path.resolve())
# --> 422         with open(path, "rb") as f:
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/snow/Copy of Copy of Copy of solar-panel-field-covered-snow-renewable-energy-winter-low-efficiency-renewable-green-energy-industry-concept-winter-211431345.jpg'

# %%
# from keras.preprocessing.image import load_img, img_to_array
from keras.utils import load_img, img_to_array
import numpy as np

img_path = "/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/no_snow/Copy of snow_on_solar_15.jpg"

# Load and preprocess your image
img = load_img(img_path, target_size=(256, 256))

# Show image
plt.imshow(img)
plt.show()

img = img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img/255.0

# Make a prediction
prediction = loaded_model.predict(img)

# Get the predicted class
predicted_class = np.argmax(prediction, axis=1)

print("")
print(class_dict[predicted_class[0]])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-670f7345e94b> in <module>
#       6
#       7 # Load and preprocess your image
# ----> 8 img = load_img(img_path, target_size=(256, 256))
#       9
#      10 # Show image
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420         if isinstance(path, pathlib.Path):
#     421             path = str(path.resolve())
# --> 422         with open(path, "rb") as f:
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/no_snow/Copy of snow_on_solar_15.jpg'

# %%
# from keras.preprocessing.image import load_img, img_to_array
from keras.utils import load_img, img_to_array
import numpy as np

img_path = "/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/no_snow/Copy of Copy of photovoltaic-home-solar-panels-work-sunny-snow-low-temperatures-performance-decreases-exponentially-255444591.jpg"

# Load and preprocess your image
img = load_img(img_path, target_size=IMAGE_SIZE)
# img = load_img(img_path, target_size=(128, 128))
# Show image
plt.imshow(img)
plt.show()

img = img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img/255.0

# Make a prediction
prediction = loaded_model.predict(img)

# Get the predicted class
predicted_class = np.argmax(prediction, axis=1)

print("")
print(class_dict[predicted_class[0]])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-2d5f8df0547c> in <module>
#       6
#       7 # Load and preprocess your image
# ----> 8 img = load_img(img_path, target_size=IMAGE_SIZE)
#       9 # img = load_img(img_path, target_size=(128, 128))
#      10 # Show image
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420         if isinstance(path, pathlib.Path):
#     421             path = str(path.resolve())
# --> 422         with open(path, "rb") as f:
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/no_snow/Copy of Copy of photovoltaic-home-solar-panels-work-sunny-snow-low-temperatures-performance-decreases-exponentially-255444591.jpg'

# %%
# from keras.preprocessing.image import load_img, img_to_array
from keras.utils import load_img, img_to_array
import numpy as np

img_path = "/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/snow/Copy of snow_on_solar_10.jpg.webp"

# Load and preprocess your image
img = load_img(img_path, target_size=(256, 256))
# img = load_img(img_path, target_size=(128, 128))
# Show image
plt.imshow(img)
plt.show()

img = img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img/255.0

# Make a prediction
prediction = loaded_model.predict(img)

# Get the predicted class
predicted_class = np.argmax(prediction, axis=1)

print("")
print(class_dict[predicted_class[0]])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-74bb92b85026> in <module>
#       6
#       7 # Load and preprocess your image
# ----> 8 img = load_img(img_path, target_size=(256, 256))
#       9 # img = load_img(img_path, target_size=(128, 128))
#      10 # Show image
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420         if isinstance(path, pathlib.Path):
#     421             path = str(path.resolve())
# --> 422         with open(path, "rb") as f:
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/snow/Copy of snow_on_solar_10.jpg.webp'

# %%
TF_MODEL_FILE_PATH = 'gdrive/MyDrive/models/snow_nosnow_detect_model.tflite' # The default path to the saved TensorFlow Lite model

interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)

# %%
interpreter.get_signature_list()
# Out:
# {'serving_default': {'inputs': ['conv2d_5_input'], 'outputs': ['dense_3']}}

# %%
# from keras.preprocessing.image import load_img, img_to_array
from keras.utils import load_img, img_to_array
import numpy as np

img_path = "/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/snow/Copy of Copy of house-roof-covered-solar-panels-winter-snow-top-energy-efficiency-maintenance-concept-195932215.jpg"

# Load and preprocess your image
img = load_img(img_path, target_size=(256, 256))
# img = load_img(img_path, target_size=(128, 128))
# Show image
plt.imshow(img)
plt.show()

img = img_to_array(img)
img = np.expand_dims(img, axis=0)
img = img/255.0

# Make a prediction
prediction = loaded_model.predict(img)

# Get the predicted class
predicted_class = np.argmax(prediction, axis=1)

print("")
print(class_dict[predicted_class[0]])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-0a0ced1ecd8d> in <module>
#       6
#       7 # Load and preprocess your image
# ----> 8 img = load_img(img_path, target_size=(256, 256))
#       9 # img = load_img(img_path, target_size=(128, 128))
#      10 # Show image
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420         if isinstance(path, pathlib.Path):
#     421             path = str(path.resolve())
# --> 422         with open(path, "rb") as f:
#     423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Snow_Covered_Solar_Panel_Detect/snow_and_nosnow_images/validate/snow/Copy of Copy of house-roof-covered-solar-panels-winter-snow-top-energy-efficiency-maintenance-concept-195932215.jpg'

# %%
predictions_lite = classify_lite(conv2d_5_input=img)['dense_3']
score_lite = tf.nn.softmax(predictions_lite)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b8648223473f> in <module>
# ----> 1 predictions_lite = classify_lite(conv2d_5_input=img)['dense_3']
#       2 score_lite = tf.nn.softmax(predictions_lite)
#
# NameError: name 'classify_lite' is not defined

# %%
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_dict[np.argmax(score_lite)], 100 * np.max(score_lite))
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f99308c6899f> in <module>
#       1 print(
#       2     "This image most likely belongs to {} with a {:.2f} percent confidence."
# ----> 3     .format(class_dict[np.argmax(score_lite)], 100 * np.max(score_lite))
#       4 )
#
# NameError: name 'score_lite' is not defined

# %%
print(np.max(np.abs(prediction - predictions_lite)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-40148c953c16> in <module>
# ----> 1 print(np.max(np.abs(prediction - predictions_lite)))
#
# NameError: name 'prediction' is not defined
