# %%
# !pip install torch
# !pip install torchvision
# Out:
# Requirement already satisfied: torch in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (2.0.0)
# Requirement already satisfied: sympy in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from torch) (1.11.1)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from torch) (3.9.0)
# Requirement already satisfied: networkx in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from torch) (2.8.4)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from torch) (3.1.2)
# Requirement already satisfied: typing-extensions in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from torch) (4.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from sympy->torch) (1.2.1)
# Collecting torchvision
#   Downloading torchvision-0.15.1-cp38-cp38-macosx_11_0_arm64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from torchvision) (9.3.0)
# Requirement already satisfied: torch==2.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from torchvision) (2.0.0)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from torch==2.0.0->torchvision) (3.1.2)
# Requirement already satisfied: typing-extensions in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from torch==2.0.0->torchvision) (4.4.0)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from torch==2.0.0->torchvision) (3.9.0)
# Requirement already satisfied: sympy in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from torch==2.0.0->torchvision) (1.11.1)
# Requirement already satisfied: networkx in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from torch==2.0.0->torchvision) (2.8.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from requests->torchvision) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from jinja2->torch==2.0.0->torchvision) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/Caskroom/miniconda/base/envs/py38/lib/python3.8/site-packages (from sympy->torch==2.0.0->torchvision) (1.2.1)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.15.1

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision

# %%
transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████| 170498071/170498071 [00:25<00:00, 6663883.79it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
batch_size = 32
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
testloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)

# %%
class CIFAR10Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=(3,3), stride=1, padding=1)
        self.act1 = nn.ReLU()
        self.drop1 = nn.Dropout(0.3)

        self.conv2 = nn.Conv2d(32, 32, kernel_size=(3,3), stride=1, padding=1)
        self.act2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=(2, 2))

        self.flat = nn.Flatten()

        self.fc3 = nn.Linear(8192, 512)
        self.act3 = nn.ReLU()
        self.drop3 = nn.Dropout(0.5)

        self.fc4 = nn.Linear(512, 10)

    def forward(self, x):
        # input 3x32x32, output 32x32x32
        x = self.act1(self.conv1(x))
        x = self.drop1(x)
        # input 32x32x32, output 32x32x32
        x = self.act2(self.conv2(x))
        # input 32x32x32, output 32x16x16
        x = self.pool2(x)
        # input 32x16x16, output 8192
        x = self.flat(x)
        # input 8192, output 512
        x = self.act3(self.fc3(x))
        x = self.drop3(x)
        # input 512, output 10
        x = self.fc4(x)
        return x

# %%
model = CIFAR10Model()
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %%
n_epochs = 20
for epoch in range(n_epochs):
    for inputs, labels in trainloader:
        # forward, backward, and then weight update
        y_pred = model(inputs)
        loss = loss_fn(y_pred, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    acc = 0
    count = 0
    for inputs, labels in testloader:
        y_pred = model(inputs)
        acc += (torch.argmax(y_pred, 1) == labels).float().sum()
        count += len(labels)
    acc /= count
    print("Epoch %d: model accuracy %.2f%%" % (epoch, acc*100))
# Out:
# Epoch 0: model accuracy 34.79%
# Epoch 1: model accuracy 41.98%
# Epoch 2: model accuracy 45.72%
# Epoch 3: model accuracy 48.55%
# Epoch 4: model accuracy 50.74%
# Epoch 5: model accuracy 53.34%
# Epoch 6: model accuracy 55.81%
# Epoch 7: model accuracy 58.07%
# Epoch 8: model accuracy 59.79%
# Epoch 9: model accuracy 62.77%
# Epoch 10: model accuracy 63.98%
# Epoch 11: model accuracy 65.55%
# Epoch 12: model accuracy 67.13%
# Epoch 13: model accuracy 68.66%
# Epoch 14: model accuracy 70.00%
# Epoch 15: model accuracy 70.86%
# Epoch 16: model accuracy 72.09%
# Epoch 17: model accuracy 72.85%
# Epoch 18: model accuracy 75.19%
# Epoch 19: model accuracy 76.03%

# %%
torch.save(model.state_dict(), "cifar10model.pth")

# %%
transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
acc += (torch.argmax(y_pred, 1) == labels).float().sum()

# %%
import matplotlib.pyplot as plt

plt.imshow(trainset.data[7])
plt.show()

# %%
X = torch.tensor([trainset.data[7]], dtype=torch.float32).permute(0,3,1,2)
model.eval()
with torch.no_grad():
    feature_maps = model.conv1(X)
# Out:
# /var/folders/7p/nhr_8mz933v_4r1mwyd3_jg40000gp/T/ipykernel_36817/2765902514.py:1: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:248.)
#   X = torch.tensor([trainset.data[7]], dtype=torch.float32).permute(0,3,1,2)

# %%
fig, ax = plt.subplots(4, 8, sharex=True, sharey=True, figsize=(16,8))
for i in range(0, 32):
    row, col = i//8, i%8
    ax[row][col].imshow(feature_maps[0][i])
plt.show()

# %%
X = torch.tensor([trainset.data[7]], dtype=torch.float32).permute(0,3,1,2)

model.eval()
with torch.no_grad():
    feature_maps = model.act1(model.conv1(X))
    feature_maps = model.drop1(feature_maps)
    feature_maps = model.conv2(feature_maps)

fig, ax = plt.subplots(4, 8, sharex=True, sharey=True, figsize=(16,8))
for i in range(0, 32):
    row, col = i//8, i%8
    ax[row][col].imshow(feature_maps[0][i])
plt.show()
