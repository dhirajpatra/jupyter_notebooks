# %%
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
import os
from shutil import copyfile
from PIL import Image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Concatenate
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping

# %%
desired_width = 224
desired_height = 224
channels = 3
num_classes = 4

# Define the image size and batch size
image_size = (desired_height, desired_width)
# Define a list of possible batch sizes as per dataset size you shoud add bigger sizes
BATCH_SIZES = [8, 16, 32]
# Generate a random index to select a batch size from the list
random_index = np.random.randint(0, len(BATCH_SIZES))

# Select a batch size using the random index
BATCH_SIZE = BATCH_SIZES[random_index]

# %%
train_images_folder = 'data/train_images'
test_images_folder = 'data/test_images'

# %%
# Read the CSV file
df = pd.read_csv("data/train.csv")
df.head()
# Out:
#          ImageId  ClassId                                      EncodedPixels
# 0  0002cc93b.jpg        1  29102 12 29346 24 29602 24 29858 24 30114 24 3...
# 1  0007a71bf.jpg        3  18661 28 18863 82 19091 110 19347 110 19603 11...
# 2  000a4bcdd.jpg        1  37607 3 37858 8 38108 14 38359 20 38610 25 388...
# 3  000f6bf48.jpg        4  131973 1 132228 4 132483 6 132738 8 132993 11 ...
# 4  0014fce06.jpg        3  229501 11 229741 33 229981 55 230221 77 230468...

# %%
# Extract the necessary columns
image_ids = df["ImageId"].tolist()
class_ids = df["ClassId"].tolist()
encoded_pixels = df["EncodedPixels"].tolist()

# %%
# # Function to extract SURF features from an image
# def extract_surf_features(image):
#     gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#     sift = cv2.SIFT_create()
#     _, des = sift.detectAndCompute(gray, None)
#     return des

# %%
def preprocess_image(image, desired_width=256, desired_height=256, uni8_required=False):
    # Check if the image is empty
    if image is None:
        print("Error: Image is empty.")
        return None
    
    # Check if the image has the correct depth
    if image.dtype != np.uint8:
        print("Error: Incorrect image depth. Expected uint8.")
        return None
    
    # Resize the image to the desired size
    resized_image = cv2.resize(image, (desired_width, desired_height))
    
    # Normalize the pixel values to a specific range (e.g., 0 to 1)
    normalized_image = resized_image / 255.0
    
    # Apply any additional preprocessing steps here
    # For example, you can perform data augmentation, apply color transformations, etc.
    
    # Convert the image to the appropriate data type (e.g., float32)
    preprocessed_image = np.float32(normalized_image)

    if uni8_required:
        # Convert the image to uint8 
        preprocessed_image = cv2.convertScaleAbs(preprocessed_image * 255.0)
    
    return preprocessed_image

# %%
# resize one image
def resize_images(source_dir, target_dir, image_path, target_size):
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)
    image = cv2.imread(image_path)
    resized_image = cv2.resize(image, target_size)
    _, filename = os.path.split(image_path)
    save_path = os.path.join(target_dir, filename)
    cv2.imwrite(save_path, resized_image)
    return resized_image

# %%
# # Load and preprocess your image data
# image = cv2.imread('./images/corrosion_image.png')

# # Check if the image is empty
# if image is None:
#     print("Error: Failed to load the image.")
#     exit()

# # Check the image depth
# if image.dtype != np.uint8:
#     print("Error: Incorrect image depth. Expected uint8.")
#     exit()

# # Preprocess the image
# image = preprocess_image(image, desired_width, desired_height, uni8_required=True)
# print(image.dtype)

# %%
# cv2.imshow('corrosion_image', image)
# cv2.waitKey()

# %%
# # Check if the preprocessed image is None
# if image is None:
#     print("Error: Failed to preprocess the image.")
#     exit()

# # Check the image depth
# if image.dtype != np.uint8:
#     print("Error: Incorrect image depth. Expected uint8.")
#     exit()


# print(image.dtype)

# # Extract SURF features from the preprocessed image
# surf_features = extract_surf_features(image)

# %%
# Function to resize an image
def resize_test_image(image_path, target_size):
    image = cv2.imread(image_path)
    resized_image = cv2.resize(image, target_size)
    return resized_image

# Iterate over the test images
for image_file in os.listdir(test_images_folder):
    # Check if the file is an image
    if image_file.lower().endswith(('.jpg', '.jpeg', '.png')):
        # Construct the path to the image file
        image_path = os.path.join(test_images_folder, image_file)

        # Resize the image
        resized_image = resize_test_image(image_path, image_size)

        # Save the resized image
        resized_image_path = os.path.join(test_images_folder, f"{image_file}")
        cv2.imwrite(resized_image_path, resized_image)

        print(f"Resized image saved: {resized_image_path}")
# Out:
# Resized image saved: data/test_images/resized_0042e163f.jpg
# Resized image saved: data/test_images/resized_002451917.jpg
# Resized image saved: data/test_images/resized_000ccc2ac.jpg
# Resized image saved: data/test_images/resized_0000f269f.jpg
# Resized image saved: data/test_images/resized_0098ca44e.jpg
# Resized image saved: data/test_images/resized_006f39c41.jpg
# Resized image saved: data/test_images/resized_004f40c73.jpg
# Resized image saved: data/test_images/resized_003c5da97.jpg
# Resized image saved: data/test_images/resized_00513039a.jpg
# Resized image saved: data/test_images/resized_008725cbc.jpg

# %%
# Create a dictionary to store class folders
class_folders = {}

# Iterate over the dataset
for image_id, class_id, encoded_pixel in zip(image_ids, class_ids, encoded_pixels):
    # Construct the path to the image file
    image_path = os.path.join(train_images_folder, image_id)

    # Check if the source file exists
    if not os.path.exists(image_path):
        print(f"Warning: Image file '{image_path}' not found. Skipping...")
        continue

    print(image_path)
    
    # Resize the image
    target_folder = os.path.join(train_images_folder, str(class_id))
    resized_image = resize_images(train_images_folder, target_folder, str(image_path), image_size)
    
    # Perform any additional preprocessing steps here
    # preprocessed_image = preprocess_image(resized_image)  # replace preprocess_image with your own preprocessing function

# Split the dataset into train and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    image_ids, class_ids, test_size=0.2, random_state=42
)
# Out:
# Warning: Image file 'data/train_images/0002cc93b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0007a71bf.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/000a4bcdd.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/000f6bf48.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0014fce06.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0025bde0c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0025bde0c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/002af848d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/002fc4e19.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/002fc4e19.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0030401a5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0046839bd.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/005d86c25.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/005f02e20.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/005f19695.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/008621629.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0088260da.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/008d0f87b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/008ef3d74.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/008ef3d74.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0095cd374.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/00ac8372f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/00ac8372f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/00af2671f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/00bc01bfe.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/00bf8497a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/00c88fed0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/00c88fed0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/00cdb56a0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/00d639396.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/00e0398ad.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/00ec97699.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/00f1665e6.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/00f6e702c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01053d28f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/010db68d1.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/012a9a4c7.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/012d29df4.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/012f26693.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/012f26693.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01338c0ea.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0139dd004.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0141c9bf3.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0148e9891.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/014ebe543.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01540cab1.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01661826d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0167a740e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/016af13d0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/016efe618.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01764ee81.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/017c828a1.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/018ccdfed.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01919944c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/019f42c2a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01a1027ce.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01afbfa7a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01b043500.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01b492dd6.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01c3ef286.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01cf446d4.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01cfacf80.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01cfacf80.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01df77e59.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01e020dc5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01ebe0d32.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01fd320c9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/01fd50e68.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/020ff3106.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0217af9b1.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0218c0fcc.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/02291e913.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/02431211b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/025cb9f6e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/025dc8dc8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/026183d85.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/02701c239.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0281aba7b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/028eb44d1.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/028ed7768.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0294f23c0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/02b2d3aa4.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/02b906933.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/02bf279c9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/02c4655ff.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/02c79bfcb.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/02d18b8a4.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/02d573611.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/02d8c6b30.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/031627893.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/031f334ec.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0340e13c4.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/03461f8e0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/034941f9d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/035021da2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0360edfb8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/036c4e5d2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/036c7d18c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/037fca267.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/03860f6a9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0386ce84b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/038f14456.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0391d44d6.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0391d44d6.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/039577d49.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/03ab4e3ea.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/03ca4d04c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/03da79fda.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/03db6bbc3.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/03db6bbc3.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/03faf7462.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/04055fd3e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0405e7c54.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/04072b39a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/041187764.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/041a93b6d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/04246167f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0429258ad.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/044700866.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/044700866.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/04594d04e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/046282f58.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/046c35525.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/047fa15d0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/048d14d3f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0498abd18.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/049bad998.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/04a06d744.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/04a4777e9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/04a5009fa.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/04ae7853c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/04c3aade7.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/04d49c95d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/04e23e414.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/04fa19d59.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/05184e71b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0518e79e9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/051f0d825.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0526d780c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/052838084.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/052ac9a54.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/052cc2a0f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0534f1b45.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/05396b495.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/053e9a29c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/054190eb2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/056e34021.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/05747b10b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0576d3847.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/057b89dd5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0582ac66c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/058a1e3b8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/059000a4f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/059327fe3.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/05a024a74.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/05d6bccf8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/05f5e7366.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0602f0520.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0603c2340.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0606395c5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/060964105.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/060c3159e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/062167783.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/063571c5c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/063fa1630.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0645d69f9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/066ecd182.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06713b712.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/068587112.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/068c6c4a9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0696cfa05.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06a01c775.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06ad83bac.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06ae96c30.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06aed81ba.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06b384e78.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06b49e34f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06d0fbb0c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06d3a99cb.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06e55cb16.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06e6582af.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06e6e7a8c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06e7b157a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06eb2151d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06f4583b1.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06f52f4dd.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/06fb3a6e5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0712fbd90.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0728b2ac9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0739e9688.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07732248e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07732248e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/077f0256d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/079054aa2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07a5651ce.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07ac7620c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07b1a9644.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07b627cb9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07ba16aba.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07ba66beb.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07c3d6d77.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07c8ba1d5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07c8ba1d5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07c8c77a3.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07c917711.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07cb6d544.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07cbfd1f8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07cbfd1f8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/07cd0a3e9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0803acf1f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0808a098b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/080d6f77f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0817e2da4.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08193cfc8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0829af407.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0832de752.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0841074c1.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0842fa725.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0849ea9f1.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/084e8ba74.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0858830b6.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/085a9eea6.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/085bcd104.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08605c0eb.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08808b1a2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08852b69d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0888e6a84.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0888e6a84.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/088a6bb94.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/088aee82e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08a1a079b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08a1a079b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08a8ed239.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08b10468d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08b40a161.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08b40a161.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08b539d11.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08c2fc120.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08d5bd03d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08d80d51a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08de8621d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08de8df60.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08de8df60.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08e3aadde.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08f0b26ac.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08f5c0997.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08f9c685f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/08f9c685f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0905fe055.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/090a6a4b5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09140dda7.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/091d21109.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/092145f0c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/092614afe.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0929b3d8f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/092f8d365.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09323504a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0934b8bff.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/093ec1c68.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/094fd70ea.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09552b326.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/096465b41.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0970201e2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09757b84e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/097e28492.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/097eaf94c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/097eaf94c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0984c380f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0986996f0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0988e13e7.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0999e53af.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/099e4e39a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09b26a624.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09b428fe0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09c967630.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09d4ee8a5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09d70d8f0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09d7dba1b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09d84ff22.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09d87038e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09e06e897.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09e15218c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09e75817a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09e9c96fd.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09ee01161.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/09f1605ee.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0a21ce787.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0a26aceb2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0a37f0a29.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0a405b396.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0a4ad45a5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0a5cff3a7.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0a8306bfe.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0a8cb8ddf.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0a9a7a6c7.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0a9aaba9a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0aa4399a4.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0aa7955fd.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0aafd7471.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0abfbfc69.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ac9936af.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0aceecf0a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0adc17f1d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ae4f8a60.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0af6b34a8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b1235e38.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b1993a49.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b1a4d585.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b1e5a7a5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b475b419.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b4a68676.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b4c8e681.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b5018316.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b5051d9f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b56da4ff.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b5c97e4c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b6cc9daa.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b76bcd3a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b77d4ddf.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b7a4c9b9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b8575001.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0b8775632.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0bb304645.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0bb37f2aa.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0bb39cafa.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0bbd121d7.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0bc0d715e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0bc373e44.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0bc373e44.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0bc3f8ce8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0bc8070d5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0bd6da716.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0bda9a0eb.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0be9bad7b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0be9bad7b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0bee4edeb.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0bfce2f41.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0bfcf7a71.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0c21c4b46.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0c2522533.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0c495b1c8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0c59df320.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0c5c5644b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0c6720401.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0c888ecb5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0c888ecb5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0c9ae816d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ca915b9f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0caf53aba.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0cb3064bd.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0cb590f8e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0cb590f8e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0cd22bad5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ce18d9e2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ce3a145f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ce5ead68.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ce6ef153.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0cefc1f4f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0cf509103.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0cfcad1f5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d0ee7a51.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d13c2a23.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d17b6b4f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d224e852.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d22c1559.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d2a4e766.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d365d98c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d3d0dbf2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d3edfec6.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d4866e3c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d4eae8de.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d51538b9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d617d477.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d661ca68.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d78ac743.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d7e52a91.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d99ab39c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0d9d2aa59.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0da0d2c17.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0da1c044f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0db448eb7.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0db535c8c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0db7ec4f0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0dc953a31.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0dd76b019.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0dd8c9f61.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ddbc9fb5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e01b820c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e0377ffa.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e0d5004d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e0f06208.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e106d482.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e1925eb6.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e232ce72.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e5981679.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e5e3f570.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e62d06d5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e650e720.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e71cd651.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e71cd651.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e7a45695.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e7f04eb4.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e86dea5b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0e9356159.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ea00bf92.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ea151b2f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0eae06feb.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0eb09950a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ebb34d89.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ebdc1277.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ec130695.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ec47dc45.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ec69ca92.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ecf31314.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ed6dadbd.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ee20797b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ee406ddb.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ef465b25.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0f010cc60.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0f010cc60.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0f0c71c3e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0f1617841.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0f2f4c90e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0f4a022fd.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0f4bf08bd.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0f65a99d2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0f7b0f4ab.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0f8305adb.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0f9a12222.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0f9f79a88.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0fa3f0dab.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0fb30b22c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0fb56c62d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0fc3d194a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0fcafcb3b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0fd171923.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0fd63823c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0fe12f041.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ff13bf69.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ff2850a2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/0ff538004.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/100cf75d9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1013a0b6e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/101648543.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/101648543.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1017c52e8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/101bc8aa5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/102ac71fd.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/10378f8ea.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/104e612c2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/105f93d9e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/106fd7aad.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1082cfe08.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1086196e1.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/108ea689b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/10909b4bb.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/10972add9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/10a3cfbce.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/10b23eabe.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/10b6f12f1.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/10bbf7cb3.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/10c05e806.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/10c190f20.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/10d98c2be.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/10d9f85be.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/10e429bfc.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/11192bc94.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/112942aed.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/112942aed.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/112b06482.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/112d183e5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/11418b1c5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/114e89e60.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/115c02850.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1165781f0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/116d673e3.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/117759a83.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/117ddaa9f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/118b71091.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1198f83d2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/11aaf18e2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/11b37e4d7.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/11b801a0a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/11bda65f0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/11bf761dc.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/11c481d5e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/11f34f40d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/11f788ecf.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/11ff6a6f4.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/121d3818a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/12234aab8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/12274ea9c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/12375dd7a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1238340e9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/123b0882e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/124204a30.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/12471d0d5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1259fbac8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/12627251e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/127504e0f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/127a4a097.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1287339e5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1287c7c74.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/128b708e5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1298b6dbb.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/12c0b2b5c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/12ca2b04b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/12d38a1d4.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/12dd3899c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/12ee58841.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/13067c801.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1308a608d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/130e11be6.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/13169e4cf.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/132511b8b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/132e8ca58.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1346c8ba2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/135a4b191.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/135be73db.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/135fe211d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1379aba8d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/137b5546d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1387583da.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1396b6e88.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/139b7e692.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/139b7e692.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/13ab7b13e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/13b66e5de.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/13c1d516a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/13c27aa5b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/13c9921d2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/13ca110ae.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/13fa1d70d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/13fa1d70d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/140e212df.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/140e59cff.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/140e59cff.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/141bea747.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/141d72a3f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1422b7da0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1422f2b27.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1435cd970.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/14457e888.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/144fdd925.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1473a83e2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/147ca5516.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1483bc52d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/14a77cc6f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/14c9a9062.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/14cc1c6b0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/14e4da366.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/14e90eb54.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/14fb9778c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/14ff2a474.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/14ff2a474.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1501f53a2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/150cadc70.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1511d97da.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1513b40a0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1524a6e4f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1535e2127.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/153b56c43.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/154e7e802.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/15547c309.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1561eb657.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/156a74a49.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1574cc730.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/15796b4d5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/157f361ec.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/159a2fee0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/159b43d49.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/15ab03ce5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/15aeb5d52.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/15b56bf43.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/15ce9e5cf.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/15d258692.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/15d8b6f02.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/15e21dfad.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/15e512a0f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/15e8d5e3d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/15ece0447.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/15f14781f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/15f8fd390.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/161ca82bf.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/162de780e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/162f17999.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/162fbb1af.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/163473240.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/16371ae14.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1639cc829.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/163cc2750.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/163ff3547.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/16498a156.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/165a55d5c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/165a55d5c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1664d4b17.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/166645a0b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/166818755.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/166fcd035.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/166fff927.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/167ae556b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/167d6930a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1699951da.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/169baf9bb.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/169bb9923.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/16a1cf5b9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/16a50624d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/16aa5333c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/16aabaf79.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/16acf1ed9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/16b7dc417.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/16b7dc417.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/16b8b50af.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/16c60441c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/16cf961d6.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/16d0b11ff.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/16d0b11ff.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1717ef156.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/171c64a72.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/172b72353.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/172e692e1.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/17383bd97.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/1740fcd28.jpg' not found. Skipping...
# ...
# Warning: Image file 'data/train_images/f8d0b85ef.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f8dcae030.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f8eb9b938.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f8f3a1eb2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f8f942505.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f8ff8457a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f901632bf.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f910b7857.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f917bca00.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f92794f0a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f94569eb5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f95284047.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f95d6f436.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f965e553b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f9668c7cd.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f9668c7cd.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f9682bef7.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f97db2626.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f98a8ae54.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f98ddb64d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f991a6a9e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f99b7c8aa.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f9a30423e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f9b337a42.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f9b98ab64.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f9d0f27a0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f9d0f27a0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/f9d912044.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa08fa8c5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa130006f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa241dde2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa342395f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa347a114.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa3828a07.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa3a68a38.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa3a68a38.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa434abec.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa6567637.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa71602c6.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa80cdac8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa8f73d4b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa9a5da40.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fa9c1b2e4.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/faa0cdf84.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/faa1000af.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/faa73f1d9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/faa80e2e8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/faab4b759.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fab50d91a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fac91988f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fac9c2cb8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/facc4ddc7.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fad2dd8ee.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fad2dd8ee.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fae50c768.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/faea44200.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fafd76f70.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb0434dea.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb18f4f82.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb1a7bc67.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb208afce.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb23968c0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb252eb78.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb2d75aea.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb352c185.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb357de4d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb357de4d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb36b84e7.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb38bb7bf.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb3a54000.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb565bc91.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb6666769.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb6a70917.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb8c8f732.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb9558035.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb9558035.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb9a07c8f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb9a07c8f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fb9bed1bb.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fbadf780f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fbb44ab31.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fbbb8f8b2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fbbd2ed0d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fbc97ac61.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fbc97ac61.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fbcb3df55.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fbd219354.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fbdc2daae.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fbdde63d5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fbf282a60.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fbf7ac43e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc0541a53.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc113cb7e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc230eb3c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc2968239.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc2d2d29e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc2d2d29e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc3151ab5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc477f3c8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc4ef4356.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc4f997c5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc4f997c5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc5e5979c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc62ebb8b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc70bf091.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc8cb11db.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fc9f88417.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fcacd299d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fcb1f2469.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fcb25f2ec.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fcce5b9cc.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fcd374576.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fcd874407.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fcddbcbc0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fcdeccead.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fcded3d29.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fcdfdbf64.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fce971b43.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fcea4a36f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fcf5cf8e2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fcfffb388.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fd14dd6dc.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fd184c14c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fd26ab9ad.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fd26ab9ad.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fd2a53b9a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fd32f8ad3.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fd3afa979.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fd5de08ea.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fd6208bbc.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fd76d8b3d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fd7b70c7b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fd86d4201.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fd88ec534.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fda1a539d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fda56a365.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fda720bac.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fdaaaf9d9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fdab86eb7.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fdabe52ee.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fdb5ae9d4.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fdb705792.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fdb7c0397.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fdb7c0397.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fdb8a4e70.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fdc83849e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fdcaa4692.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fdd363326.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fde8d37fc.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fdefeca1f.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fdf0d8b7a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fdf3a16fc.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe01b0ce0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe1f25a02.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe21a795a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe2234ba6.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe2234ba6.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe2637bd9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe335d9b8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe65bce69.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe689cf0a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe6f8e502.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe793c552.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe7b99496.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe8e137c0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe90516f3.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fe96a088d.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fea2f6ad2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fea3da755.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fea4c4feb.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fea8e46ad.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/feb2cfa94.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/febd24f9a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fec4b10d0.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fec86da3c.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fed07ccf3.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fed23a483.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fee93875b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/feebe80d4.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/feec56162.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff001adfe.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff1020719.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff27b4b1b.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff300484e.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff44fa556.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff4ddccf9.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff52f9fe2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff5483763.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff5590fbe.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff5c7f868.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff6bfada2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff6bfada2.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff6cc90ca.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff6e35e0a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff6e35e0a.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff933e271.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff96dfa95.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff9923932.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ff9d46e95.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ffb48ee43.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ffbd081d5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ffc9fdf70.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ffcf72ecf.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fff02e9c5.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/fffe98443.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ffff4eaa8.jpg' not found. Skipping...
# Warning: Image file 'data/train_images/ffffd67df.jpg' not found. Skipping...

# %%
train_images = []
test_images = []

# %%
# Preprocess train images
for filename in os.listdir(train_images_folder):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        image_path = os.path.join(train_images_folder, filename)
        image = cv2.imread(image_path)
        preprocessed_image = preprocess_image(image, desired_width, desired_height)
        train_images.append(preprocessed_image)

train_images = np.array(train_images)

# %%
# Preprocess test images
for filename in os.listdir(test_images_folder):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        image_path = os.path.join(test_images_folder, filename)
        image = cv2.imread(image_path)
        preprocessed_image = preprocess_image(image, desired_width, desired_height)
        test_images.append(preprocessed_image)

test_images = np.array(test_images)

# %%
# Print the shape of the preprocessed images
print("Train images shape:", train_images.shape)
print("Test images shape:", test_images.shape)
# Out:
# Train images shape: (0,)
# Test images shape: (10, 224, 224, 3)

# %%
# Create an instance of ImageDataGenerator for the test set
test_datagen = ImageDataGenerator(
    rescale=1./255   # Rescale the pixel values to the range [0, 1]
)

# Create an instance of ImageDataGenerator for the training set
train_datagen = ImageDataGenerator(
    rescale=1./255,      # Rescale the pixel values to the range [0, 1]
    rotation_range=20,   # Randomly rotate the images by up to 20 degrees
    width_shift_range=0.2,  # Randomly shift the images horizontally by up to 20% of the image width
    height_shift_range=0.2, # Randomly shift the images vertically by up to 20% of the image height
    shear_range=0.2,         # Randomly shear the images by up to 20%
    zoom_range=0.3,          # Randomly zoom the images by up to 20%
    horizontal_flip=True,    # Randomly flip the images horizontally
    vertical_flip=True,
    brightness_range = (0.8, 1.2), # brightness adjuster so that some partial images can detect when ground is dark
    fill_mode='nearest',      # Fill any empty pixels with the nearest available pixel value
    featurewise_center=False,
    featurewise_std_normalization=False,
    data_format='channels_last',
    validation_split=0.2
)

# Normalize the data
train_datagen.mean = [123.68, 116.779, 103.939] # RGB channel mean values from ImageNet
train_datagen.std = [58.393, 57.12, 57.375]

# Use the flow_from_directory method to load the images from the directory
train_generator = train_datagen.flow_from_directory(
    train_images_folder,                 # Path to the training set directory
    target_size=image_size,    # Resize the images to 256x256
    batch_size=BATCH_SIZE,             # Use batches of 32 images
    class_mode='categorical',   # Use categorical cross-entropy loss
    subset='training',
    shuffle=True  # Shuffle the files from different folders
)

# Load the validation data into x_val and y_val
validation_generator = train_datagen.flow_from_directory(
    directory=train_images_folder,
    target_size=image_size,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

# Load the test data into x_test and y_test
test_generator = test_datagen.flow_from_directory(
    directory=test_images_folder,
    target_size=image_size,
    batch_size=BATCH_SIZE//2,
    class_mode='categorical'
)

# Handle any exceptions that may occur during data generation
try:
    x_train, y_train = next(train_generator)
except Exception as e:
    print(f"Error during training data generation: {e}")
    
try:
    x_val, y_val = next(validation_generator)
except Exception as e:
    print(f"Error during validation data generation: {e}")

try:
    x_test, y_test = next(test_generator)
except Exception as e:
    print(f"Error during test data generation: {e}")
# Out:
# Found 50 images belonging to 4 classes.
# Found 9 images belonging to 4 classes.
# Found 0 images belonging to 0 classes.

# %%
# Load the pre-trained VGG16 model without the top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(desired_height, desired_width, channels))

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# %%
# Create a new model and add the pre-trained VGG16 base
model = Sequential()
model.add(base_model)

# Add custom layers for classification
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_5 (Flatten)         (None, 25088)             0
#
#  dense_10 (Dense)            (None, 256)               6422784
#
#  dense_11 (Dense)            (None, 4)                 1028
#
# =================================================================
# Total params: 21138500 (80.64 MB)
# Trainable params: 6423812 (24.50 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
# Define the EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, mode='max', verbose=1)

# %%
# Train the model with early stopping
history = model.fit(train_generator, epochs=100, validation_data=validation_generator, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 2/2 [==============================] - 2s 1s/step - loss: 4.0926 - accuracy: 0.2600 - val_loss: 2.9410 - val_accuracy: 0.6667
# Epoch 2/100
# 2/2 [==============================] - 1s 354ms/step - loss: 4.8973 - accuracy: 0.5400 - val_loss: 3.8895 - val_accuracy: 0.2222
# Epoch 3/100
# 2/2 [==============================] - 1s 628ms/step - loss: 4.9712 - accuracy: 0.3400 - val_loss: 2.3689 - val_accuracy: 0.6667
# Epoch 4/100
# 2/2 [==============================] - 1s 356ms/step - loss: 4.6903 - accuracy: 0.5400 - val_loss: 2.0837 - val_accuracy: 0.6667
# Epoch 5/100
# 2/2 [==============================] - 1s 553ms/step - loss: 2.7872 - accuracy: 0.5800 - val_loss: 1.5289 - val_accuracy: 0.6667
# Epoch 6/100
# 2/2 [==============================] - 1s 581ms/step - loss: 2.2055 - accuracy: 0.2600 - val_loss: 2.1491 - val_accuracy: 0.0000e+00
# Epoch 6: early stopping

# %%
# Check if the desired accuracy and validation accuracy thresholds are met
if history.history['accuracy'][-1] >= 0.95 and history.history['val_accuracy'][-1] >= 0.8:
    print("Early stopping criteria met!")

# %%
# Iterate over the test images
for image_file in os.listdir(test_images_folder):
    # Load and preprocess the test image
    image_path = os.path.join(test_images_folder, image_file)
    if image_file.endswith(".jpg") or image_file.endswith(".png"):
        test_image = cv2.imread(image_path)
        
        if test_image is None:
            print(f"Error loading image: {image_path}")
            continue
        
        # Reshape the test image
        test_image_input = np.expand_dims(test_image, axis=0)
        
        # Make predictions on the test image
        predictions = model.predict(test_image_input)
        
        # Get the predicted class label
        predicted_class_label = np.argmax(predictions)
        
        # Print the predicted class label for the test image
        print(f"Test image: {image_file} - Predicted class label: {predicted_class_label}")
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Test image: resized_0042e163f.jpg - Predicted class label: 1
# 1/1 [==============================] - 0s 17ms/step
# Test image: resized_002451917.jpg - Predicted class label: 1
# 1/1 [==============================] - 0s 16ms/step
# Test image: resized_000ccc2ac.jpg - Predicted class label: 1
# 1/1 [==============================] - 0s 16ms/step
# Test image: resized_0000f269f.jpg - Predicted class label: 2
# 1/1 [==============================] - 0s 18ms/step
# Test image: resized_0098ca44e.jpg - Predicted class label: 1
# 1/1 [==============================] - 0s 18ms/step
# Test image: resized_006f39c41.jpg - Predicted class label: 1
# 1/1 [==============================] - 0s 18ms/step
# Test image: resized_004f40c73.jpg - Predicted class label: 1
# 1/1 [==============================] - 0s 18ms/step
# Test image: resized_003c5da97.jpg - Predicted class label: 2
# 1/1 [==============================] - 0s 17ms/step
# Test image: resized_00513039a.jpg - Predicted class label: 1
# 1/1 [==============================] - 0s 17ms/step
# Test image: resized_008725cbc.jpg - Predicted class label: 1
