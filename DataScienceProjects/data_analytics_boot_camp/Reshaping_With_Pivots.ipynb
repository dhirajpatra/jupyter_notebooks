# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.0.3'

# %% [markdown]
# #### New Data: New York City SAT Scores
#
# > https://andybek.com/pandas-sat
#
# *...also attached as a resource!*

# %%
sat_url = 'https://andybek.com/pandas-sat'

# %%
sat = pd.read_csv(sat_url)

# %%
sat.head()
# Out:
#                              School Name    Borough  ...  SAT Section Score
# 0  A. Philip Randolph Campus High School  Manhattan  ...         Math   459
# 1  A. Philip Randolph Campus High School  Manhattan  ...      Reading   453
# 2  A. Philip Randolph Campus High School  Manhattan  ...      Writing   447
# 3            Abraham Lincoln High School   Brooklyn  ...         Math   441
# 4            Abraham Lincoln High School   Brooklyn  ...      Reading   422
#
# [5 rows x 6 columns]

# %%
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1125 entries, 0 to 1124
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   School Name         1125 non-null   object
#  1   Borough             1125 non-null   object
#  2   Student Enrollment  1125 non-null   int64
#  3   Percent Tested      1125 non-null   object
#  4   SAT Section         1125 non-null   object
#  5   Score               1125 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 52.9+ KB

# %%
sat['Percent Tested'] = sat['Percent Tested'].replace(regex='%', value='').astype(float)

# %%
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1125 entries, 0 to 1124
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   School Name         1125 non-null   object
#  1   Borough             1125 non-null   object
#  2   Student Enrollment  1125 non-null   int64
#  3   Percent Tested      1125 non-null   float64
#  4   SAT Section         1125 non-null   object
#  5   Score               1125 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 52.9+ KB

# %% [markdown]
# #### Pivoting Data

# %%
sat.head(9)
# Out:
#                                   School Name    Borough  ...  SAT Section  Score
# 0       A. Philip Randolph Campus High School  Manhattan  ...         Math    459
# 1       A. Philip Randolph Campus High School  Manhattan  ...      Reading    453
# 2       A. Philip Randolph Campus High School  Manhattan  ...      Writing    447
# 3                 Abraham Lincoln High School   Brooklyn  ...         Math    441
# 4                 Abraham Lincoln High School   Brooklyn  ...      Reading    422
# 5                 Abraham Lincoln High School   Brooklyn  ...      Writing    422
# 6  Academy for Careers in Television and Film     Queens  ...         Math    444
# 7  Academy for Careers in Television and Film     Queens  ...      Reading    458
# 8  Academy for Careers in Television and Film     Queens  ...      Writing    444
#
# [9 rows x 6 columns]

# %%
sat.set_index(['School Name', 'SAT Section'])
# Out:
#                                                           Borough  ...  Score
# School Name                                SAT Section             ...
# A. Philip Randolph Campus High School      Math         Manhattan  ...    459
#                                            Reading      Manhattan  ...    453
#                                            Writing      Manhattan  ...    447
# Abraham Lincoln High School                Math          Brooklyn  ...    441
#                                            Reading       Brooklyn  ...    422
# ...                                                           ...  ...    ...
# Young Women's Leadership School in Astoria Reading         Queens  ...    464
#                                            Writing         Queens  ...    477
# Young Women's Leadership School in Queens  Math            Queens  ...    415
#                                            Reading         Queens  ...    420
# ...

# %%
sat.set_index(['School Name', 'SAT Section']).loc[:, ['Score']]
# Out:
#                                                         Score
# School Name                                SAT Section
# A. Philip Randolph Campus High School      Math           459
#                                            Reading        453
#                                            Writing        447
# Abraham Lincoln High School                Math           441
#                                            Reading        422
# ...                                                       ...
# Young Women's Leadership School in Astoria Reading        464
#                                            Writing        477
# Young Women's Leadership School in Queens  Math           415
#                                            Reading        420
#                                            Writing        433
#
# [1125 rows x 1 columns]

# %%
sat.set_index(['School Name', 'SAT Section']).loc[:, ['Score']].unstack(level=1)
# Out:
#                                                    Score
# SAT Section                                         Math Reading Writing
# School Name
# A. Philip Randolph Campus High School                459     453     447
# ACORN Community High School                          379     395     385
# Abraham Lincoln High School                          441     422     422
# Academy for Careers in Television and Film           444     458     444
# Academy for College Preparation and Career Expl...   386     397     393
# ...                                                  ...     ...     ...
# World Journalism Preparatory (College Board)         484     491     487
# York Early College Academy                           496     481     473
# Young Women's Leadership School                      478     465     472
# Young Women's Leadership School in Astoria           483     464     477
# Young Women's Leadership School in Queens            415     420     433
#
# [375 rows x 3 columns]

# %%
sat.pivot('School Name', 'SAT Section', 'Score')
# Out:
# SAT Section                                         Math  Reading  Writing
# School Name
# A. Philip Randolph Campus High School                459      453      447
# ACORN Community High School                          379      395      385
# Abraham Lincoln High School                          441      422      422
# Academy for Careers in Television and Film           444      458      444
# Academy for College Preparation and Career Expl...   386      397      393
# ...                                                  ...      ...      ...
# World Journalism Preparatory (College Board)         484      491      487
# York Early College Academy                           496      481      473
# Young Women's Leadership School                      478      465      472
# Young Women's Leadership School in Astoria           483      464      477
# Young Women's Leadership School in Queens            415      420      433
#
# [375 rows x 3 columns]

# %%
pivoted = sat.pivot(index='School Name', columns='SAT Section', values='Score')

# %%
pivoted.head()
# Out:
# SAT Section                                         Math  Reading  Writing
# School Name
# A. Philip Randolph Campus High School                459      453      447
# ACORN Community High School                          379      395      385
# Abraham Lincoln High School                          441      422      422
# Academy for Careers in Television and Film           444      458      444
# Academy for College Preparation and Career Expl...   386      397      393

# %%
sat.head()
# Out:
#                              School Name    Borough  ...  SAT Section  Score
# 0  A. Philip Randolph Campus High School  Manhattan  ...         Math    459
# 1  A. Philip Randolph Campus High School  Manhattan  ...      Reading    453
# 2  A. Philip Randolph Campus High School  Manhattan  ...      Writing    447
# 3            Abraham Lincoln High School   Brooklyn  ...         Math    441
# 4            Abraham Lincoln High School   Brooklyn  ...      Reading    422
#
# [5 rows x 6 columns]

# %% [markdown]
# #### Undoing Pivots

# %%
# Q: how do do you "undo" a pivot?

# %%
# the "cheat":

  # scores_by_borough = scores pivoted by borough
  # scores_by_school = scores pivoted by school
  # enrollment_by_school = enrollment pivoted by school
  # ...

# %%
pivoted
# Out:
# SAT Section                                         Math  Reading  Writing
# School Name
# A. Philip Randolph Campus High School                459      453      447
# ACORN Community High School                          379      395      385
# Abraham Lincoln High School                          441      422      422
# Academy for Careers in Television and Film           444      458      444
# Academy for College Preparation and Career Expl...   386      397      393
# ...                                                  ...      ...      ...
# World Journalism Preparatory (College Board)         484      491      487
# York Early College Academy                           496      481      473
# Young Women's Leadership School                      478      465      472
# Young Women's Leadership School in Astoria           483      464      477
# Young Women's Leadership School in Queens            415      420      433
#
# [375 rows x 3 columns]

# %%
pivoted.stack().reset_index()
# Out:
#                                      School Name SAT Section    0
# 0          A. Philip Randolph Campus High School        Math  459
# 1          A. Philip Randolph Campus High School     Reading  453
# 2          A. Philip Randolph Campus High School     Writing  447
# 3                    ACORN Community High School        Math  379
# 4                    ACORN Community High School     Reading  395
# ...                                          ...         ...  ...
# 1120  Young Women's Leadership School in Astoria     Reading  464
# 1121  Young Women's Leadership School in Astoria     Writing  477
# 1122   Young Women's Leadership School in Queens        Math  415
# 1123   Young Women's Leadership School in Queens     Reading  420
# 1124   Young Women's Leadership School in Queens     Writing  433
#
# [1125 rows x 3 columns]

# %%
# the melt() method

# %%
pivoted.head()
# Out:
# SAT Section                                         Math  Reading  Writing
# School Name
# A. Philip Randolph Campus High School                459      453      447
# ACORN Community High School                          379      395      385
# Abraham Lincoln High School                          441      422      422
# Academy for Careers in Television and Film           444      458      444
# Academy for College Preparation and Career Expl...   386      397      393

# %%
pivoted.reset_index().melt()
# Out:
#       SAT Section                                              value
# 0     School Name              A. Philip Randolph Campus High School
# 1     School Name                        ACORN Community High School
# 2     School Name                        Abraham Lincoln High School
# 3     School Name         Academy for Careers in Television and Film
# 4     School Name  Academy for College Preparation and Career Exp...
# ...           ...                                                ...
# 1495      Writing                                                487
# 1496      Writing                                                473
# 1497      Writing                                                472
# 1498      Writing                                                477
# 1499      Writing                                                433
#
# [1500 rows x 2 columns]

# %%
pivoted.reset_index().melt(id_vars='School Name', value_name='Score')
# Out:
#                                             School Name SAT Section  Score
# 0                 A. Philip Randolph Campus High School        Math    459
# 1                           ACORN Community High School        Math    379
# 2                           Abraham Lincoln High School        Math    441
# 3            Academy for Careers in Television and Film        Math    444
# 4     Academy for College Preparation and Career Exp...        Math    386
# ...                                                 ...         ...    ...
# 1120       World Journalism Preparatory (College Board)     Writing    487
# 1121                         York Early College Academy     Writing    473
# 1122                    Young Women's Leadership School     Writing    472
# 1123         Young Women's Leadership School in Astoria     Writing    477
# 1124          Young Women's Leadership School in Queens     Writing    433
#
# [1125 rows x 3 columns]

# %% [markdown]
# #### What About Aggregates?

# %%
pivoted.head(3)
# Out:
# SAT Section                            Math  Reading  Writing
# School Name
# A. Philip Randolph Campus High School   459      453      447
# ACORN Community High School             379      395      385
# Abraham Lincoln High School             441      422      422

# %%
sat.head(3)
# Out:
#                              School Name    Borough  ...  SAT Section  Score
# 0  A. Philip Randolph Campus High School  Manhattan  ...         Math    459
# 1  A. Philip Randolph Campus High School  Manhattan  ...      Reading    453
# 2  A. Philip Randolph Campus High School  Manhattan  ...      Writing    447
#
# [3 rows x 6 columns]

# %%
sat.Borough.unique()
# Out:
# array(['Manhattan', 'Brooklyn', 'Queens', 'Bronx', 'Staten Island'],
#       dtype=object)

# %%
# Q: what is the average SAT score by borough?

# %%
sat.pivot(index='School Name', columns='SAT Section', values='Score')
# Out:
# SAT Section                                         Math  Reading  Writing
# School Name
# A. Philip Randolph Campus High School                459      453      447
# ACORN Community High School                          379      395      385
# Abraham Lincoln High School                          441      422      422
# Academy for Careers in Television and Film           444      458      444
# Academy for College Preparation and Career Expl...   386      397      393
# ...                                                  ...      ...      ...
# World Journalism Preparatory (College Board)         484      491      487
# York Early College Academy                           496      481      473
# Young Women's Leadership School                      478      465      472
# Young Women's Leadership School in Astoria           483      464      477
# Young Women's Leadership School in Queens            415      420      433
#
# [375 rows x 3 columns]

# %%
# sat.pivot(index='Borough', columns='SAT Section', values='Score')

# %%
sat.set_index('Borough')
# Out:
#                                           School Name  ...  Score
# Borough                                                ...
# Manhattan       A. Philip Randolph Campus High School  ...    459
# Manhattan       A. Philip Randolph Campus High School  ...    453
# Manhattan       A. Philip Randolph Campus High School  ...    447
# Brooklyn                  Abraham Lincoln High School  ...    441
# Brooklyn                  Abraham Lincoln High School  ...    422
# ...                                               ...  ...    ...
# Queens     Young Women's Leadership School in Astoria  ...    464
# Queens     Young Women's Leadership School in Astoria  ...    477
# Queens      Young Women's Leadership School in Queens  ...    415
# Queens      Young Women's Leadership School in Queens  ...    420
# Queens      Young Women's Leadership School in Queens  ...    433
#
# [1125 rows x 5 columns]

# %% [markdown]
# #### The pivot_table()

# %%
# previously: 

# sat.pivot(index='Borough', columns='SAT Section', values='Score')

# %%
sat.pivot_table(values='Score', index='Borough', columns='SAT Section')
# Out:
# SAT Section          Math     Reading     Writing
# Borough
# Bronx          404.357143  402.520408  395.846939
# Brooklyn       416.403670  410.761468  403.091743
# Manhattan      455.887640  444.932584  439.314607
# Queens         462.362319  443.260870  439.855072
# Staten Island  486.200000  478.500000  474.300000

# %%
sat.pivot_table(values='Score', index='Borough', columns='SAT Section', aggfunc='std')
# Out:
# SAT Section         Math    Reading    Writing
# Borough
# Bronx          52.215898  49.224340  51.304298
# Brooklyn       60.481420  48.914684  49.657072
# Manhattan      83.818315  73.930987  76.387707
# Queens         71.890229  61.712724  66.233383
# Staten Island  83.132825  66.850164  72.671330

# %%
# Q: what is the average percent tested by borough?

# %%
sat.head()
# Out:
#                              School Name    Borough  ...  SAT Section  Score
# 0  A. Philip Randolph Campus High School  Manhattan  ...         Math    459
# 1  A. Philip Randolph Campus High School  Manhattan  ...      Reading    453
# 2  A. Philip Randolph Campus High School  Manhattan  ...      Writing    447
# 3            Abraham Lincoln High School   Brooklyn  ...         Math    441
# 4            Abraham Lincoln High School   Brooklyn  ...      Reading    422
#
# [5 rows x 6 columns]

# %%
# ACT

# %%
sat.pivot_table(values='Percent Tested', index='Borough')
# Out:
#                Percent Tested
# Borough
# Bronx               58.220408
# Brooklyn            62.423853
# Manhattan           71.197753
# Queens              69.036232
# Staten Island       67.390000

# %%
sat.pivot_table(values='Percent Tested', index='Borough', aggfunc='min')
# Out:
#                Percent Tested
# Borough
# Bronx                    19.2
# Brooklyn                 18.5
# Manhattan                30.6
# Queens                   26.3
# Staten Island            38.0

# %% [markdown]
# #### BONUS: The Problem With Average Percentage

# %%
sat.pivot_table(values='Percent Tested', index='Borough', aggfunc='mean')
# Out:
#                Percent Tested
# Borough
# Bronx               58.220408
# Brooklyn            62.423853
# Manhattan           71.197753
# Queens              69.036232
# Staten Island       67.390000

# %%
# Andy said (and corrected myself):
  # on average, 40% of students from the Bronx and Brooklyn end up not taking the SAT

# %%
# ===ASIDE

# %%
# school A: 100 students, 30% took the SAT, 30
# school B: 1000 students, 60% took the SAT, 600

# %%
(.3 + .6) / 2
# Out:
# 0.44999999999999996

# %%
(30 + 600) / (100 + 1000)
# Out:
# 0.5727272727272728

# %%
# ===END ASIDE

# %%
sat.head()
# Out:
#                              School Name    Borough  ...  Score  SAT Takers
# 0  A. Philip Randolph Campus High School  Manhattan  ...    459    1001.960
# 1  A. Philip Randolph Campus High School  Manhattan  ...    453    1001.960
# 2  A. Philip Randolph Campus High School  Manhattan  ...    447    1001.960
# 3            Abraham Lincoln High School   Brooklyn  ...    441    1285.209
# 4            Abraham Lincoln High School   Brooklyn  ...    422    1285.209
#
# [5 rows x 7 columns]

# %%
sat['SAT Takers'] = sat['Percent Tested'] * sat['Student Enrollment'] / 100

# %%
sat.pivot_table(values='SAT Takers', index='Borough', aggfunc='mean')
# Out:
#                 SAT Takers
# Borough
# Bronx           322.523888
# Brooklyn        498.704807
# Manhattan       477.360876
# Queens          747.937551
# Staten Island  1271.262500

# %%
sat.pivot_table(values='Student Enrollment', index='Borough', aggfunc='mean')
# Out:
#                Student Enrollment
# Borough
# Bronx                  541.724490
# Brooklyn               742.550459
# Manhattan              638.089888
# Queens                1122.884058
# Staten Island         1846.000000

# %%
sat.groupby(['Borough'])[['Student Enrollment', 'SAT Takers']]\
   .apply(lambda sg: sg['SAT Takers'].mean() / sg['Student Enrollment'].mean())\
   .nsmallest(10)
# Out:
# Borough
# Bronx            0.595365
# Queens           0.666086
# Brooklyn         0.671611
# Staten Island    0.688658
# Manhattan        0.748109
# dtype: float64

# %% [markdown]
# #### Replicating Pivot Tables With GroupBy

# %%
sat.pivot_table('Score','Borough','SAT Section')
# Out:
# SAT Section          Math     Reading     Writing
# Borough
# Bronx          404.357143  402.520408  395.846939
# Brooklyn       416.403670  410.761468  403.091743
# Manhattan      455.887640  444.932584  439.314607
# Queens         462.362319  443.260870  439.855072
# Staten Island  486.200000  478.500000  474.300000

# %%
sat.groupby(['Borough', 'SAT Section']).agg({'Score':'mean'}).unstack()
# Out:
#                     Score
# SAT Section          Math     Reading     Writing
# Borough
# Bronx          404.357143  402.520408  395.846939
# Brooklyn       416.403670  410.761468  403.091743
# Manhattan      455.887640  444.932584  439.314607
# Queens         462.362319  443.260870  439.855072
# Staten Island  486.200000  478.500000  474.300000

# %% [markdown]
# #### Adding Margins

# %%
sat.pivot_table('Score', 'Borough', 'SAT Section', aggfunc='mean', margins=True)
# Out:
# SAT Section          Math     Reading     Writing         All
# Borough
# Bronx          404.357143  402.520408  395.846939  400.908163
# Brooklyn       416.403670  410.761468  403.091743  410.085627
# Manhattan      455.887640  444.932584  439.314607  446.711610
# Queens         462.362319  443.260870  439.855072  448.492754
# Staten Island  486.200000  478.500000  474.300000  479.666667
# All            432.944000  424.504000  418.458667  425.302222

# %%
sat[sat.Borough == 'Manhattan'].Score.mean()
# Out:
# 446.7116104868914

# %%
sat.Score.mean()
# Out:
# 425.3022222222222

# %%
sat.pivot_table('Score', 'Borough')
# Out:
#                     Score
# Borough
# Bronx          400.908163
# Brooklyn       410.085627
# Manhattan      446.711610
# Queens         448.492754
# Staten Island  479.666667

# %%
sat.pivot_table('Score', 'SAT Section')
# Out:
#                   Score
# SAT Section
# Math         432.944000
# Reading      424.504000
# Writing      418.458667

# %%
sat.pivot_table('Score', 'Borough', 'SAT Section', aggfunc='max', margins=True, margins_name='Grand Total')
# Out:
# SAT Section    Math  Reading  Writing  Grand Total
# Borough
# Bronx           714      672      672          714
# Brooklyn        682      608      606          682
# Manhattan       754      697      693          754
# Queens          701      640      661          701
# Staten Island   711      660      670          711
# Grand Total     754      697      693          754

# %% [markdown]
# #### MultiIndex Pivot Tables

# %%
# pivot tables = groupby + agg + multiindex

# %%
sat.pivot_table(values='Score', columns=['School Name', 'Borough'], index='SAT Section')
# Out:
# School Name A. Philip Randolph Campus High School  ... Young Women's Leadership School in Queens
# Borough                                 Manhattan  ...                                    Queens
# SAT Section                                        ...
# Math                                          459  ...                                       415
# Reading                                       453  ...                                       420
# Writing                                       447  ...                                       433
#
# [3 rows x 375 columns]

# %%
sat.pivot_table(values='Score', columns=['School Name', 'Borough'], index='SAT Section').T.T
# Out:
# School Name A. Philip Randolph Campus High School  ... Young Women's Leadership School in Queens
# Borough                                 Manhattan  ...                                    Queens
# SAT Section                                        ...
# Math                                          459  ...                                       415
# Reading                                       453  ...                                       420
# Writing                                       447  ...                                       433
#
# [3 rows x 375 columns]

# %% [markdown]
# #### Applying Multiple Functions

# %%
# previously: 
        sat.pivot_table('Score', 'Borough', 'SAT Section')
# Out:
# SAT Section          Math     Reading     Writing
# Borough
# Bronx          404.357143  402.520408  395.846939
# Brooklyn       416.403670  410.761468  403.091743
# Manhattan      455.887640  444.932584  439.314607
# Queens         462.362319  443.260870  439.855072
# Staten Island  486.200000  478.500000  474.300000

# %%
sat.pivot_table('Score', 'Borough', 'SAT Section', aggfunc='max')
# Out:
# SAT Section    Math  Reading  Writing
# Borough
# Bronx           714      672      672
# Brooklyn        682      608      606
# Manhattan       754      697      693
# Queens          701      640      661
# Staten Island   711      660      670

# %%
# Q: show the minimum and maximum SAT section scores by borough, in one pivot table

# %%
sat.pivot_table('Score', 'Borough', 'SAT Section', aggfunc=[np.min, np.max])
# Out:
#               amin                 amax
# SAT Section   Math Reading Writing Math Reading Writing
# Borough
# Bronx          317     311     292  714     672     672
# Brooklyn       319     302     284  682     608     606
# Manhattan      344     330     316  754     697     693
# Queens         340     320     318  701     640     661
# Staten Island  420     427     409  711     660     670

# %%
# np.min -> alias for np.amin

# %%
sat.pivot_table('Score', 'Borough', 'SAT Section', aggfunc=[np.min, np.max]).rename(axis=1, level=0, mapper={'amin':'Minmumu', 'amax':'Maximum'})
# Out:
#               Minmumu                 Maximum
# SAT Section      Math Reading Writing    Math Reading Writing
# Borough
# Bronx             317     311     292     714     672     672
# Brooklyn          319     302     284     682     608     606
# Manhattan         344     330     316     754     697     693
# Queens            340     320     318     701     640     661
# Staten Island     420     427     409     711     660     670

# %% [markdown]
# #### Skill Challenge

# %% [markdown]
# ###### **1.**

# %% [markdown]
# Starting with our main dataframe (*sat*), create a pivot table that summarizes the <ins>total</ins> student enrollment (Student Enrollment) across all 5 boroughs (*Borough*).
#
# Which boroughs have the highest and lowest high school student bodies?

# %% [markdown]
# ###### **2.**

# %% [markdown]
# Modify the pivot table from the step above to also reflect the average student body size (*Student Enrollment*) across boroughs, in the same pivot table.

# %% [markdown]
# ###### 🔥🔥 🚒 **3.**

# %% [markdown]
# Create a pivot table of high schools from the Queens borough (*Borough*), containing the SAT section scores (*SAT Section*, *Score*) as columns and the school name (*School Name*) as index. Sort the table in descending order by math section scores.

# %% [markdown]
# #### Solution

# %%
sat.head()
# Out:
#                              School Name    Borough  ...  Score  SAT Takers
# 0  A. Philip Randolph Campus High School  Manhattan  ...    459    1001.960
# 1  A. Philip Randolph Campus High School  Manhattan  ...    453    1001.960
# 2  A. Philip Randolph Campus High School  Manhattan  ...    447    1001.960
# 3            Abraham Lincoln High School   Brooklyn  ...    441    1285.209
# 4            Abraham Lincoln High School   Brooklyn  ...    422    1285.209
#
# [5 rows x 7 columns]

# %%
# 1

# %%
sat.pivot_table('Student Enrollment', 'Borough', aggfunc='sum').sort_values(by='Student Enrollment', ascending=False)
# Out:
#                Student Enrollment
# Borough
# Brooklyn                   242814
# Queens                     232437
# Manhattan                  170370
# Bronx                      159267
# Staten Island               55380

# %%
sat.pivot_table('Student Enrollment', 'Borough', aggfunc='sum').nlargest(50, columns='Student Enrollment')
# Out:
#                Student Enrollment
# Borough
# Brooklyn                   242814
# Queens                     232437
# Manhattan                  170370
# Bronx                      159267
# Staten Island               55380

# %%
sat.pivot_table('Student Enrollment', 'Borough', aggfunc='sum').idxmin()
# Out:
# Student Enrollment    Staten Island
# dtype: object

# %%
sat.pivot_table('Student Enrollment', 'Borough', aggfunc='sum').idxmax()
# Out:
# Student Enrollment    Brooklyn
# dtype: object

# %%
# 2

# %%
sat.pivot_table('Student Enrollment', 'Borough', aggfunc=['sum', 'mean'])
# Out:
#                              sum               mean
#               Student Enrollment Student Enrollment
# Borough
# Bronx                     159267         541.724490
# Brooklyn                  242814         742.550459
# Manhattan                 170370         638.089888
# Queens                    232437        1122.884058
# Staten Island              55380        1846.000000

# %%
# 3

# %%
# - queens schools
# - a pivot table of scores (by sat section), school names
# - sorted descending by math section scores

# %%
sat[sat.Borough == 'Queens']\
  .pivot_table('Score', 'School Name', 'SAT Section')\
  .sort_values(by='Math', ascending=False)
# Out:
# SAT Section                                         Math  Reading  Writing
# School Name
# Queens High School for the Sciences at York Col...   701      621      625
# Townsend Harris High School                          680      640      661
# Baccalaureate School for Global Education            633      620      628
# Bard High School Early College Queens                631      598      610
# Scholars' Academy                                    588      560      568
# ...                                                  ...      ...      ...
# Middle College High School at LaGuardia Communi...   377      389      377
# Queens High School for Information, Research, a...   372      362      352
# August Martin High School                            366      372      364
# Rockaway Park High School for Environmental Sus...   357      381      376
# Pan American International High School               340      320      318
#
# [69 rows x 3 columns]
