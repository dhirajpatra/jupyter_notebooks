# %% [markdown]
# # Data Visualization

# %%
import seaborn as sns
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df3 = pd.DataFrame(np.random.rand(10,4))

# %%
df3
# Out:
#           0         1         2         3
# 0  0.664440  0.086252  0.068838  0.570592
# 1  0.871906  0.616083  0.489543  0.575830
# 2  0.084810  0.334317  0.055953  0.468366
# 3  0.161478  0.032116  0.285629  0.337213
# 4  0.273301  0.557540  0.256702  0.566342
# 5  0.650715  0.709175  0.288522  0.334220
# 6  0.478587  0.934580  0.875453  0.104753
# 7  0.865062  0.725394  0.549824  0.966546
# 8  0.268103  0.827232  0.872136  0.390821
# 9  0.928718  0.072168  0.917375  0.218760

# %%
df3.plot.bar()
# Out:
# <Axes: >

# %%
df3.plot.barh()
# Out:
# <Axes: >

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df1 = sns.load_dataset('iris')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1['petal_width'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind = 'hist' , stacked = True , bins = 15 , figsize = (10,15) , title = "histogram of iris")
# Out:
# <Axes: title={'center': 'histogram of iris'}, ylabel='Frequency'>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df1.hist(figsize= (5,10) , color = '#862d2d' , alpha  = .6, sharex=False)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df1.plot.scatter(x = 'sepal_width' , y = 'petal_width')
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_width'>

# %%
df1.plot.scatter(x = 'sepal_length' , y = 'petal_width', c = 'petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.plot.scatter(x  ='sepal_length' , y  = 'sepal_width', label = 'Arihant' ,s = 5 ,c = 'petal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.hexbin(x  ='sepal_length' , y  = 'sepal_width', label = 'Arihant' ,gridsize = 5)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
np.random.seed(100)
df = pd.DataFrame(np.random.rand(1000,1) , index=pd.date_range('2021-07-18' , periods=1000), columns=['data'])

# %%
df
# Out:
#                 data
# 2021-07-18  0.543405
# 2021-07-19  0.278369
# 2021-07-20  0.424518
# 2021-07-21  0.844776
# 2021-07-22  0.004719
# ...              ...
# 2024-04-08  0.656403
# 2024-04-09  0.291456
# 2024-04-10  0.150869
# 2024-04-11  0.036932
# 2024-04-12  0.597964
#
# [1000 rows x 1 columns]

# %%
df['data1'] = df.data.cumsum()

# %%
df
# Out:
#                 data       data1
# 2021-07-18  0.543405    0.543405
# 2021-07-19  0.278369    0.821774
# 2021-07-20  0.424518    1.246292
# 2021-07-21  0.844776    2.091068
# 2021-07-22  0.004719    2.095787
# ...              ...         ...
# 2024-04-08  0.656403  497.103821
# 2024-04-09  0.291456  497.395277
# 2024-04-10  0.150869  497.546146
# 2024-04-11  0.036932  497.583078
# 2024-04-12  0.597964  498.181042
#
# [1000 rows x 2 columns]

# %%
df['data2'] = df.data + df.data1

# %%
df
# Out:
#                 data       data1       data2
# 2021-07-18  0.543405    0.543405    1.086810
# 2021-07-19  0.278369    0.821774    1.100144
# 2021-07-20  0.424518    1.246292    1.670810
# 2021-07-21  0.844776    2.091068    2.935844
# 2021-07-22  0.004719    2.095787    2.100506
# ...              ...         ...         ...
# 2024-04-08  0.656403  497.103821  497.760224
# 2024-04-09  0.291456  497.395277  497.686733
# 2024-04-10  0.150869  497.546146  497.697015
# 2024-04-11  0.036932  497.583078  497.620010
# 2024-04-12  0.597964  498.181042  498.779006
#
# [1000 rows x 3 columns]

# %%
d = df.iloc[0]

# %%
d
# Out:
# data     0.543405
# data1    0.543405
# data2    1.086810
# Name: 2021-07-18 00:00:00, dtype: float64

# %%
d.plot.pie(y='data', figsize=(10, 10), subplots=False)
# Out:
# <Axes: ylabel='2021-07-18 00:00:00'>

# %%
iris = df1.head(3).T

# %%
df1.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
iris
# Out:
#                    0       1       2
# sepal_length     5.1     4.9     4.7
# sepal_width      3.5     3.0     3.2
# petal_length     1.4     1.4     1.3
# petal_width      0.2     0.2     0.2
# species       setosa  setosa  setosa

# %%
iris.iloc[0:4].plot.pie(subplots = True , figsize = (20,20) ,fontsize = 10 , autopct = '%.3f')
# Out:
# array([<Axes: ylabel='0'>, <Axes: ylabel='1'>, <Axes: ylabel='2'>],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(df1 , figsize = (10,10))
# Out:
# array([[<Axes: xlabel='sepal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_width'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_length'>,
#         <Axes: xlabel='petal_length', ylabel='petal_length'>,
#         <Axes: xlabel='petal_width', ylabel='petal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_width'>,
#         <Axes: xlabel='petal_length', ylabel='petal_width'>,
# ...

# %%
pd.plotting.scatter_matrix(df1 , figsize = (10,10), diagonal='kde')
# Out:
# array([[<Axes: xlabel='sepal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_width'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_length'>,
#         <Axes: xlabel='petal_length', ylabel='petal_length'>,
#         <Axes: xlabel='petal_width', ylabel='petal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_width'>,
#         <Axes: xlabel='petal_length', ylabel='petal_width'>,
# ...

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,9],'r--')

plt.show()

# %%
plt.plot([1,2,3],[4,5,9],'r*-',)

# %%
plt.plot([1,2,3],[4,5,9],'r*',linestyle='dashed',markersize=40)

# %%
import matplotlib.pyplot as plt
x=[5,10,12]
y=[6,1,13]
plt.plot(x,y)
plt.title('info')
plt.ylabel('Age')
plt.xlabel('Salary')
plt.savefig('test_pie.jpg')

# %%
pwd
# Out:
# '/Users/Admin/Desktop/python/jupyter_notebooks/DataScienceProjects/IIT-G applied data science, ml and edge ai/IIT_6M/03_Data_Visualization'

# %%
x=np.arange(0, 4*np.pi, 0.1)
y=np.sin(x)
plt.plot(x,y)
plt.title("Sine wave")
# Out:
# Text(0.5, 1.0, 'Sine wave')

# %%
values = [4,1,5,7,8,3]
col=['b','g','c','m','y','r']
lab=['A','B','C','D','E','F']
exp=[0,0,0,0.2,0,0]
plt.pie(values, colors=col, labels=lab, explode=exp, autopct='%.f%%', counterclock=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x29cdd1220>,
# ...
#  [Text(0.9910657451172095, 0.47727213291294374, 'A'),
#   Text(0.5852352421222552, 0.931396645569494, 'B'),
#   Text(-0.12316099315989822, 1.0930834230578503, 'C'),
#   Text(-1.29182588405542, 0.14555371958295218, 'D'),
#   Text(1.2873679044788556e-07, -1.0999999999999925, 'E'),
#   Text(1.0382717216510535, -0.36330680150495037, 'F')],
#  [Text(0.5405813155184778, 0.2603302543161511, '14%'),
#   Text(0.3192192229757755, 0.5080345339469966, '4%'),
#   Text(-0.06717872354176266, 0.5962273216679184, '18%'),
#   Text(-0.7949697748033353, 0.08957151974335519, '25%'),
#   Text(7.022006751702848e-08, -0.5999999999999959, '29%'),
#   Text(0.5663300299914836, -0.19816734627542745, '11%')])

# %%
import seaborn as sns
import numpy as np

# Generate random data
np.random.seed(42)
data = np.random.normal(0, 1, 1000)

# Create KDE plot using Seaborn
sns.kdeplot(data, shade=True)

# Add labels and title
sns.set_style("whitegrid")
sns.set_palette("colorblind")
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Kernel Density Estimation Plot")

# Show the plot
plt.show()
# Out:
# /var/folders/7p/nhr_8mz933v_4r1mwyd3_jg40000gp/T/ipykernel_49822/1641906456.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data, shade=True)
