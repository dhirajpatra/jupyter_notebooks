# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d salader/dogs-vs-cats
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading dogs-vs-cats.zip to /content
# 100% 1.06G/1.06G [00:27<00:00, 43.1MB/s]
# 100% 1.06G/1.06G [00:27<00:00, 41.0MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/dogs-vs-cats.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Flatten
from keras.applications.vgg16 import VGG16

# %%
conv_base = VGG16(
    weights='imagenet',
    include_top = False,
    input_shape=(150,150,3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step

# %%
model = Sequential()

model.add(conv_base)
model.add(Flatten())
model.add(Dense(256,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
conv_base.trainable = False

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
batch_size = 32

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        '/content/train',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='binary') 

validation_generator = test_datagen.flow_from_directory(
        '/content/test',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='binary')
# Out:
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit_generator(
        train_generator,
        epochs=10,
        validation_data=validation_generator)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   after removing the cwd from sys.path.
# Epoch 1/10
# 625/625 [==============================] - 188s 287ms/step - loss: 0.2981 - accuracy: 0.8719 - val_loss: 0.2182 - val_accuracy: 0.9050
# Epoch 2/10
# 625/625 [==============================] - 170s 272ms/step - loss: 0.2396 - accuracy: 0.8963 - val_loss: 0.2197 - val_accuracy: 0.9076
# Epoch 3/10
# 625/625 [==============================] - 171s 274ms/step - loss: 0.2206 - accuracy: 0.9036 - val_loss: 0.1904 - val_accuracy: 0.9202
# Epoch 4/10
# 625/625 [==============================] - 171s 274ms/step - loss: 0.2013 - accuracy: 0.9157 - val_loss: 0.1975 - val_accuracy: 0.9172
# Epoch 5/10
# 625/625 [==============================] - 171s 273ms/step - loss: 0.1979 - accuracy: 0.9165 - val_loss: 0.2027 - val_accuracy: 0.9142
# Epoch 6/10
# 625/625 [==============================] - 171s 274ms/step - loss: 0.1904 - accuracy: 0.9201 - val_loss: 0.1960 - val_accuracy: 0.9180
# Epoch 7/10
# 625/625 [==============================] - 170s 272ms/step - loss: 0.1761 - accuracy: 0.9257 - val_loss: 0.1940 - val_accuracy: 0.9238
# Epoch 8/10
# 625/625 [==============================] - 170s 272ms/step - loss: 0.1708 - accuracy: 0.9273 - val_loss: 0.2021 - val_accuracy: 0.9178
# Epoch 9/10
# 625/625 [==============================] - 170s 272ms/step - loss: 0.1631 - accuracy: 0.9322 - val_loss: 0.1935 - val_accuracy: 0.9200
# Epoch 10/10
# 625/625 [==============================] - 169s 270ms/step - loss: 0.1605 - accuracy: 0.9327 - val_loss: 0.2057 - val_accuracy: 0.9124

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()
