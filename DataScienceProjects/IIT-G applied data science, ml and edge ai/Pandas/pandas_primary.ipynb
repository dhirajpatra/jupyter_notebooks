# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

# %%
pd.DataFrame({'Yes':[40,20],'No':[50,10]})
# Out:
#    Yes  No
# 0   40  50
# 1   20  10

# %%
pd.DataFrame({'Bob':['man', 'age 40'], 'Sam':['woman', 'age 42']})
# Out:
#       Bob     Sam
# 0     man   woman
# 1  age 40  age 42

# %%
pd.DataFrame({'Bob':['man', 'age 40'], 'Sam':['woman', 'age 42']}, index=['Product A', 'Product B'])
# Out:
#               Bob     Sam
# Product A     man   woman
# Product B  age 40  age 42

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([1,2,3,4,5], index=['good', 'bad', 'very good', 'moderate', 'ok'], name='just test')
# Out:
# good         1
# bad          2
# very good    3
# moderate     4
# ok           5
# Name: just test, dtype: int64

# %%
df = pd.DataFrame([[4,7,10],
                  [5,8,11],
                  [6,9,12]],
                 index=[1,2,3],
                 columns=['a','b','c'])
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
pd.melt(df)
# Out:
#   variable  value
# 0        a      4
# 1        a      5
# 2        a      6
# 3        b      7
# 4        b      8
# 5        b      9
# 6        c     10
# 7        c     11
# 8        c     12

# %%
adf = pd.DataFrame([['A',1],
                   ['B',2],
                   ['C',3]],
                  index=[1,2,3],
                  columns=['x1','x2'])
adf
# Out:
#   x1  x2
# 1  A   1
# 2  B   2
# 3  C   3

# %%
bdf = pd.DataFrame([['A',True],
                   ['B',False],
                   ['D',True]],
                  index=[1,2,3],
                  columns=['x1','x3'])
bdf
# Out:
#   x1     x3
# 1  A   True
# 2  B  False
# 3  D   True

# %%
pd.merge(adf, bdf, how='left', on='x1')
# Out:
#   x1  x2     x3
# 0  A   1   True
# 1  B   2  False
# 2  C   3    NaN

# %%
pd.merge(adf, bdf, how='right', on='x1')
# Out:
#   x1   x2     x3
# 0  A  1.0   True
# 1  B  2.0  False
# 2  D  NaN   True

# %%
pd.merge(adf, bdf, how='inner', on='x1')
# Out:
#   x1  x2     x3
# 0  A   1   True
# 1  B   2  False

# %%
pd.merge(adf, bdf, how='outer', on='x1')
# Out:
#   x1   x2     x3
# 0  A  1.0   True
# 1  B  2.0  False
# 2  C  3.0    NaN
# 3  D  NaN   True

# %%
adf[adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 1  A   1
# 2  B   2

# %%
wine_reviews = pd.read_csv("data/winequality-red.csv")

# %%
wine_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine_reviews.shape
# Out:
# (1599, 12)

# %%
wine_reviews.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wine_reviews.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine_reviews.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
pH = wine_reviews['pH']
pH.head()
# Out:
# 0    3.51
# 1    3.20
# 2    3.26
# 3    3.16
# 4    3.51
# Name: pH, dtype: float64

# %%
print(type(pH))
print(pH.shape)
# Out:
# <class 'pandas.core.series.Series'>
# (1599,)

# %%
alcohol_quality = wine_reviews[['alcohol', 'quality']]
print(type(alcohol_quality))
print(alcohol_quality.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (1599, 2)

# %%
high_alcohol = wine_reviews[wine_reviews['alcohol'] > 10]
high_alcohol
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 9               7.5             0.500         0.36             6.1      0.071
# 11              7.5             0.500         0.36             6.1      0.071
# 16              8.5             0.280         0.56             1.8      0.092
# 30              6.7             0.675         0.07             2.4      0.089
# 31              6.9             0.685         0.00             2.5      0.105
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# alcoholo either 11.0 or 10.5
wine_reviews[wine_reviews['alcohol'].isin([11.0, 10.5])].shape
# Out:
# (126, 12)

# %%
wine_reviews[(wine_reviews['alcohol'] == 11.0) | (wine_reviews['alcohol'] == 10.5)].shape
# Out:
# (126, 12)

# %%
wine_reviews[wine_reviews['alcohol'].notna()].shape
# Out:
# (1599, 12)

# %%
wine_reviews[wine_reviews['alcohol'].isnull()].shape
# Out:
# (0, 12)

# %%
# number of rows to display rows from 11 till 20 and col 4 till 6
test_wine_reviews = wine_reviews.iloc[10:20, 3:6]
test_wine_reviews
# Out:
#     residual sugar  chlorides  free sulfur dioxide
# 10             1.8      0.097                 15.0
# 11             6.1      0.071                 17.0
# 12             1.6      0.089                 16.0
# 13             1.6      0.114                  9.0
# 14             3.8      0.176                 52.0
# 15             3.9      0.170                 51.0
# 16             1.8      0.092                 35.0
# 17             1.7      0.368                 16.0
# 18             4.4      0.086                  6.0
# 19             1.8      0.341                 17.0

# %%
test_wine_reviews[test_wine_reviews['free sulfur dioxide'] < 10] = 10.0
test_wine_reviews
# Out:
#     residual sugar  chlorides  free sulfur dioxide
# 10             1.8      0.097                 15.0
# 11             6.1      0.071                 17.0
# 12             1.6      0.089                 16.0
# 13            10.0     10.000                 10.0
# 14             3.8      0.176                 52.0
# 15             3.9      0.170                 51.0
# 16             1.8      0.092                 35.0
# 17             1.7      0.368                 16.0
# 18            10.0     10.000                 10.0
# 19             1.8      0.341                 17.0

# %%
# a specific row as col
wine_reviews.loc[2]
# Out:
# fixed acidity            7.800
# volatile acidity         0.760
# citric acid              0.040
# residual sugar           2.300
# chlorides                0.092
# free sulfur dioxide     15.000
# total sulfur dioxide    54.000
# density                  0.997
# pH                       3.260
# sulphates                0.650
# alcohol                  9.800
# quality                  5.000
# Name: 2, dtype: float64

# %%
high_alcohol = wine_reviews.groupby('alcohol').first()
high_alcohol
# Out:
#            fixed acidity  volatile acidity  citric acid  residual sugar  \
# alcohol
# 8.400000            10.4              0.61         0.49             2.1
# 8.500000            10.0              0.38         0.38             1.6
# 8.700000             7.9              0.24         0.40             1.6
# 8.800000             9.9              0.50         0.50            13.8
# 9.000000             7.4              0.59         0.08             4.4
# ...                  ...               ...          ...             ...
# 13.500000            5.8              0.29         0.26             1.7
# 13.566667            5.3              0.47         0.11             2.2
# 13.600000            5.0              0.40         0.50             4.3
# 14.000000            5.2              0.34         0.00             1.8
# 14.900000           15.9              0.36         0.65             7.5
#
#            chlorides  free sulfur dioxide  total sulfur dioxide  density  \
# alcohol
# ...

# %%
high_alcohol.loc[1:10].head()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# alcohol
# 8.4               10.4              0.61         0.49             2.1
# 8.5               10.0              0.38         0.38             1.6
# 8.7                7.9              0.24         0.40             1.6
# 8.8                9.9              0.50         0.50            13.8
# 9.0                7.4              0.59         0.08             4.4
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# alcohol
# 8.4          0.200                  5.0                  16.0  0.99940  3.16
# 8.5          0.169                 27.0                  90.0  0.99914  3.15
# 8.7          0.056                 11.0                  25.0  0.99670  3.32
# 8.8          0.205                 48.0                  82.0  1.00242  3.16
# 9.0          0.086                  6.0                  29.0  0.99740  3.38
#
#          sulphates  quality
# alcohol
# ...

# %%
high_alcohol.loc[[8.4, 8.5], ['chlorides']]
# Out:
#          chlorides
# alcohol
# 8.4          0.200
# 8.5          0.169

# %%
high_alcohol.iloc[[8.4, 8.5], [4]]
# Out:
#           chlorides
# alcohol
# 9.233333      0.074
# 9.233333      0.074

# %%
f = high_alcohol.iloc[[8.4, 8.5], [4]].copy(deep=False)
f
# Out:
#           chlorides
# alcohol
# 9.233333      0.074
# 9.233333      0.074

# %%
f['copy_test'] = pd.Series([1, 2], index=["a", "b"])
f.drop(columns='copy_test')
# Out:
#           chlorides
# alcohol
# 9.233333      0.074
# 9.233333      0.074

# %%
wine_reviews['chlorides'].max()
# Out:
# 0.611

# %%
test_wine_reviews.plot()
# Out:
# <AxesSubplot:>

# %%
test_wine_reviews['chlorides'].plot()
# Out:
# <AxesSubplot:>

# %%
wine_reviews.plot.scatter(x="residual sugar", y="chlorides", alpha=0.5)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='chlorides'>

# %%
wine_reviews['alcohol'].plot.box()
# Out:
# <AxesSubplot:>

# %%
axs = wine_reviews['alcohol'].plot.area(figsize=(12,4), subplots=True)

# %%
deadly_wine = test_wine_reviews
deadly_wine['alcohol'] = wine_reviews['alcohol'] * 2
print(deadly_wine)
deadly_wine['> 20'] = False
deadly_wine['> 20'] = deadly_wine['alcohol'] > 20
print(deadly_wine.head())
# Out:
#     residual sugar  chlorides  free sulfur dioxide  alcohol
# 10             1.8      0.097                 15.0     18.4
# 11             6.1      0.071                 17.0     21.0
# 12             1.6      0.089                 16.0     19.8
# 13            10.0     10.000                 10.0     18.2
# 14             3.8      0.176                 52.0     18.4
# 15             3.9      0.170                 51.0     18.4
# 16             1.8      0.092                 35.0     21.0
# 17             1.7      0.368                 16.0     18.6
# 18            10.0     10.000                 10.0     18.0
# 19             1.8      0.341                 17.0     18.4
#     residual sugar  chlorides  free sulfur dioxide  alcohol   > 20
# 10             1.8      0.097                 15.0     18.4  False
# 11             6.1      0.071                 17.0     21.0   True
# 12             1.6      0.089                 16.0     19.8  False
# ...

# %%
deadly_wine['residual sugar'].median()
# Out:
# 2.8

# %%
deadly_wine.iloc[:,2:4].groupby('alcohol').median()
# Out:
#          free sulfur dioxide
# alcohol
# 18.0                    10.0
# 18.2                    10.0
# 18.4                    34.0
# 18.6                    16.0
# 19.8                    16.0
# 21.0                    26.0

# %%
deadly_wine.iloc[:,2:4].value_counts()
# Out:
# free sulfur dioxide  alcohol
# 10.0                 18.0       1
#                      18.2       1
# 15.0                 18.4       1
# 16.0                 18.6       1
#                      19.8       1
# 17.0                 18.4       1
#                      21.0       1
# 35.0                 21.0       1
# 51.0                 18.4       1
# 52.0                 18.4       1
# dtype: int64

# %%
test_wine_reviews.sort_values(by=['alcohol'], ascending=False).head()
# Out:
#     residual sugar  chlorides  free sulfur dioxide  alcohol   > 20
# 11             6.1      0.071                 17.0     21.0   True
# 16             1.8      0.092                 35.0     21.0   True
# 12             1.6      0.089                 16.0     19.8  False
# 17             1.7      0.368                 16.0     18.6  False
# 10             1.8      0.097                 15.0     18.4  False

# %%
test_wine_reviews.sort_index().groupby(['alcohol']).head()
# Out:
#     residual sugar  chlorides  free sulfur dioxide  alcohol   > 20
# 10             1.8      0.097                 15.0     18.4  False
# 11             6.1      0.071                 17.0     21.0   True
# 12             1.6      0.089                 16.0     19.8  False
# 13            10.0     10.000                 10.0     18.2  False
# 14             3.8      0.176                 52.0     18.4  False
# 15             3.9      0.170                 51.0     18.4  False
# 16             1.8      0.092                 35.0     21.0   True
# 17             1.7      0.368                 16.0     18.6  False
# 18            10.0     10.000                 10.0     18.0  False
# 19             1.8      0.341                 17.0     18.4  False

# %%
residual_sugar_chlorides = test_wine_reviews.pivot(columns=['residual sugar'], values="chlorides")
residual_sugar_chlorides
# Out:
# residual sugar   1.6    1.7    1.8    3.8   3.9    6.1   10.0
# 10                NaN    NaN  0.097    NaN   NaN    NaN   NaN
# 11                NaN    NaN    NaN    NaN   NaN  0.071   NaN
# 12              0.089    NaN    NaN    NaN   NaN    NaN   NaN
# 13                NaN    NaN    NaN    NaN   NaN    NaN  10.0
# 14                NaN    NaN    NaN  0.176   NaN    NaN   NaN
# 15                NaN    NaN    NaN    NaN  0.17    NaN   NaN
# 16                NaN    NaN  0.092    NaN   NaN    NaN   NaN
# 17                NaN  0.368    NaN    NaN   NaN    NaN   NaN
# 18                NaN    NaN    NaN    NaN   NaN    NaN  10.0
# 19                NaN    NaN  0.341    NaN   NaN    NaN   NaN

# %%
test_wine_reviews.pivot(columns='alcohol', values='free sulfur dioxide').plot()
# Out:
# <AxesSubplot:>

# %%
test_wine_reviews.melt(id_vars='alcohol')
# Out:
#     alcohol             variable  value
# 0      18.4       residual sugar    1.8
# 1      21.0       residual sugar    6.1
# 2      19.8       residual sugar    1.6
# 3      18.2       residual sugar   10.0
# 4      18.4       residual sugar    3.8
# 5      18.4       residual sugar    3.9
# 6      21.0       residual sugar    1.8
# 7      18.6       residual sugar    1.7
# 8      18.0       residual sugar   10.0
# 9      18.4       residual sugar    1.8
# 10     18.4            chlorides  0.097
# 11     21.0            chlorides  0.071
# 12     19.8            chlorides  0.089
# 13     18.2            chlorides   10.0
# 14     18.4            chlorides  0.176
# 15     18.4            chlorides   0.17
# 16     21.0            chlorides  0.092
# 17     18.6            chlorides  0.368
# 18     18.0            chlorides   10.0
# 19     18.4            chlorides  0.341
# 20     18.4  free sulfur dioxide   15.0
# 21     21.0  free sulfur dioxide   17.0
# ...

# %%
pd.concat([wine_reviews, test_wine_reviews], axis=0)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4              0.70         0.00             1.9      0.076
# 1             7.8              0.88         0.00             2.6      0.098
# 2             7.8              0.76         0.04             2.3      0.092
# 3            11.2              0.28         0.56             1.9      0.075
# 4             7.4              0.70         0.00             1.9      0.076
# ..            ...               ...          ...             ...        ...
# 15            NaN               NaN          NaN             3.9      0.170
# 16            NaN               NaN          NaN             1.8      0.092
# 17            NaN               NaN          NaN             1.7      0.368
# 18            NaN               NaN          NaN            10.0     10.000
# 19            NaN               NaN          NaN             1.8      0.341
#
# ...

# %%
pd.merge(wine_reviews, test_wine_reviews, how="left")
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
electric = pd.read_csv('data/Electric_Production.csv')
electric.head()
# Out:
#        DATE  IPG2211A2N
# 0  1/1/1985     72.5052
# 1  2/1/1985     70.6720
# 2  3/1/1985     62.4502
# 3  4/1/1985     57.4714
# 4  5/1/1985     55.3151

# %%
electric['date_time'] = pd.to_datetime(electric['DATE'])
electric.head()
# Out:
#        DATE  IPG2211A2N  date_time
# 0  1/1/1985     72.5052 1985-01-01
# 1  2/1/1985     70.6720 1985-02-01
# 2  3/1/1985     62.4502 1985-03-01
# 3  4/1/1985     57.4714 1985-04-01
# 4  5/1/1985     55.3151 1985-05-01

# %%
electric['month'] = electric['date_time'].dt.month
electric.head()
# Out:
#        DATE  IPG2211A2N  date_time  month
# 0  1/1/1985     72.5052 1985-01-01      1
# 1  2/1/1985     70.6720 1985-02-01      2
# 2  3/1/1985     62.4502 1985-03-01      3
# 3  4/1/1985     57.4714 1985-04-01      4
# 4  5/1/1985     55.3151 1985-05-01      5

# %%
electric.groupby(electric['date_time'].dt.weekday)['IPG2211A2N'].mean()
# Out:
# date_time
# 0    89.421589
# 1    88.732995
# 2    88.729811
# 3    89.373631
# 4    88.766464
# 5    88.681166
# 6    88.241842
# Name: IPG2211A2N, dtype: float64

# %%
test_electric = electric.pivot(index='DATE', columns='date_time')
test_electric["1985-01-01":"1985-01-02"].plot()
test_electric.dropna()
# plt.show()
# Out:
# Empty DataFrame
# ...

# %%
# creating a dataframe
df = pd.DataFrame({'A': ['Mr. John', 'Mr. Boby', 'Mrs. Mina', 'Mr. Peter', 'Mis. Nicky'],
      'B': ['Masters', 'Graduate', 'Graduate', 'Masters', 'Graduate'],
      'C': [27, 23, 21, 23, 24],
       'D': ['male', 'male', 'female', 'male', 'female']})
df
# Out:
#             A         B   C       D
# 0    Mr. John   Masters  27    male
# 1    Mr. Boby  Graduate  23    male
# 2   Mrs. Mina  Graduate  21  female
# 3   Mr. Peter   Masters  23    male
# 4  Mis. Nicky  Graduate  24  female

# %%
# values can be an object or a list
df.pivot('A', 'B', 'C')
# Out:
# B           Graduate  Masters
# A
# Mis. Nicky      24.0      NaN
# Mr. Boby        23.0      NaN
# Mr. John         NaN     27.0
# Mr. Peter        NaN     23.0
# Mrs. Mina       21.0      NaN

# %%
# value is a list
df.pivot(index ='A', columns ='B', values =['C', 'A'])
# Out:
#                   C                   A
# B          Graduate Masters    Graduate    Masters
# A
# Mis. Nicky       24     NaN  Mis. Nicky        NaN
# Mr. Boby         23     NaN    Mr. Boby        NaN
# Mr. John        NaN      27         NaN   Mr. John
# Mr. Peter       NaN      23         NaN  Mr. Peter
# Mrs. Mina        21     NaN   Mrs. Mina        NaN

# %%
# Simplest pivot table must have a dataframe
# and an index/list of index.
table = pd.pivot_table(df, index =['A', 'B'])
table
# Out:
#                       C
# A          B
# Mis. Nicky Graduate  24
# Mr. Boby   Graduate  23
# Mr. John   Masters   27
# Mr. Peter  Masters   23
# Mrs. Mina  Graduate  21

# %%
# Creates a pivot table dataframe
table = pd.pivot_table(df, values ='A', index =['B', 'C'], columns =['B'], aggfunc = np.sum)
table
# Out:
# B              Graduate    Masters Graduate Masters
# B        C
# Graduate 21   Mrs. Mina        NaN   female     NaN
#          23    Mr. Boby        NaN     male     NaN
#          24  Mis. Nicky        NaN   female     NaN
# Masters  23         NaN  Mr. Peter      NaN    male
#          27         NaN   Mr. John      NaN    male

# %%
df['A'].str.lower()
# Out:
# 0      mr. john
# 1      mr. boby
# 2     mrs. mina
# 3     mr. peter
# 4    mis. nicky
# Name: A, dtype: object

# %%
# get first part of name
df['A'].str.split(' ').str.get(0)
# Out:
# 0     Mr.
# 1     Mr.
# 2    Mrs.
# 3     Mr.
# 4    Mis.
# Name: A, dtype: object

# %%
df['A'].str.contains('p')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: A, dtype: bool

# %%
df['A'].str.len()
# Out:
# 0     8
# 1     8
# 2     9
# 3     9
# 4    10
# Name: A, dtype: int64

# %%
df['D'] = df['D'].replace({"male": "M", "female": "F"})

# %%
df
# Out:
#             A         B   C  D
# 0    Mr. John   Masters  27  M
# 1    Mr. Boby  Graduate  23  M
# 2   Mrs. Mina  Graduate  21  F
# 3   Mr. Peter   Masters  23  M
# 4  Mis. Nicky  Graduate  24  F

# %%
dates_lst_1 = pd.date_range('2020-01-06', '2022-12-25', freq="MS")
dates_lst_1
# Out:
# DatetimeIndex(['2020-02-01', '2020-03-01', '2020-04-01', '2020-05-01',
#                '2020-06-01', '2020-07-01', '2020-08-01', '2020-09-01',
#                '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01',
#                '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01',
#                '2021-06-01', '2021-07-01', '2021-08-01', '2021-09-01',
#                '2021-10-01', '2021-11-01', '2021-12-01', '2022-01-01',
#                '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01',
#                '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01',
#                '2022-10-01', '2022-11-01', '2022-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
i = pd.date_range('2022-01-01', periods=5, freq='2D')
i
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-03', '2022-01-05', '2022-01-07',
#                '2022-01-09'],
#               dtype='datetime64[ns]', freq='2D')

# %%
ts = pd.DataFrame({'A': [1, 2, 3, 4, 5]}, index=i)
ts
# Out:
#             A
# 2022-01-01  1
# 2022-01-03  2
# 2022-01-05  3
# 2022-01-07  4
# 2022-01-09  5

# %%
df
# Out:
#             A         B   C  D
# 0    Mr. John   Masters  27  M
# 1    Mr. Boby  Graduate  23  M
# 2   Mrs. Mina  Graduate  21  F
# 3   Mr. Peter   Masters  23  M
# 4  Mis. Nicky  Graduate  24  F

# %%
df.set_index(i, inplace=True)
df
# Out:
#                      A         B   C  D
# 2022-01-01    Mr. John   Masters  27  M
# 2022-01-03    Mr. Boby  Graduate  23  M
# 2022-01-05   Mrs. Mina  Graduate  21  F
# 2022-01-07   Mr. Peter   Masters  23  M
# 2022-01-09  Mis. Nicky  Graduate  24  F

# %%
df == 'Masters'
# Out:
#                 A      B      C      D
# 2022-01-01  False   True  False  False
# 2022-01-03  False  False  False  False
# 2022-01-05  False  False  False  False
# 2022-01-07  False   True  False  False
# 2022-01-09  False  False  False  False

# %%
df['D'] == 'F'
# Out:
# 2022-01-01    False
# 2022-01-03    False
# 2022-01-05     True
# 2022-01-07    False
# 2022-01-09     True
# Freq: 2D, Name: D, dtype: bool

# %%
df_test = pd.DataFrame(np.arange(18).reshape(6,3))
colnames = pd.DataFrame({'Names': ['A', 'B', 'C', 'D', 'E', 'F'],
                    'foo': [0, 1, 0, 0, 0, 0]})
df_test.set_index(colnames['Names'], inplace=True)
df_test
# Out:
#         0   1   2
# Names
# A       0   1   2
# B       3   4   5
# C       6   7   8
# D       9  10  11
# E      12  13  14
# F      15  16  17

# %%
wine_reviews
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_reviews.groupby(['pH']).mean()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# pH
# 2.74           9.20            0.5200        1.000           3.400     0.6100
# 2.86          14.30            0.3100        0.740           1.800     0.0750
# 2.87           9.20            0.7550        0.180           2.200     0.1480
# 2.88          11.30            0.5000        0.415           1.800     0.0780
# 2.89           9.35            0.3050        0.380           1.550     0.0775
# ...             ...               ...          ...             ...        ...
# 3.75           5.00            1.0200        0.040           1.400     0.0450
# 3.78           5.30            0.5325        0.135           2.075     0.0860
# 3.85           4.70            0.6000        0.170           2.300     0.0580
# 3.90           4.85            0.4950        0.085           1.700     0.0440
# 4.01           5.20            0.7400        0.000           1.200     0.0410
#
# ...

# %%
arrays = [['falcon', 'falcon','parrot'], ['captive', 'wild', 'captive']]
index = pd.MultiIndex.from_arrays(arrays, names=('Animal', 'Type'))
df = pd.DataFrame({'MAX speed': [390.0, 350, 30]}, index=index)
df
# Out:
#                 MAX speed
# Animal Type
# falcon captive      390.0
#        wild         350.0
# parrot captive       30.0

# %%
wine_reviews.groupby(by=['pH'], dropna=False).sum()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# pH
# 2.74            9.2             0.520         1.00            3.40      0.610
# 2.86           14.3             0.310         0.74            1.80      0.075
# 2.87            9.2             0.755         0.18            2.20      0.148
# 2.88           22.6             1.000         0.83            3.60      0.156
# 2.89           37.4             1.220         1.52            6.20      0.310
# ...             ...               ...          ...             ...        ...
# 3.75            5.0             1.020         0.04            1.40      0.045
# 3.78           10.6             1.065         0.27            4.15      0.172
# 3.85            4.7             0.600         0.17            2.30      0.058
# 3.90            9.7             0.990         0.17            3.40      0.088
# 4.01           10.4             1.480         0.00            2.40      0.082
#
# ...

# %%
wine_reviews.groupby('pH').quantile()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# pH
# 2.74           9.20            0.5200        1.000           3.400     0.6100
# 2.86          14.30            0.3100        0.740           1.800     0.0750
# 2.87           9.20            0.7550        0.180           2.200     0.1480
# 2.88          11.30            0.5000        0.415           1.800     0.0780
# 2.89           9.35            0.3050        0.380           1.550     0.0775
# ...             ...               ...          ...             ...        ...
# 3.75           5.00            1.0200        0.040           1.400     0.0450
# 3.78           5.30            0.5325        0.135           2.075     0.0860
# 3.85           4.70            0.6000        0.170           2.300     0.0580
# 3.90           4.85            0.4950        0.085           1.700     0.0440
# 4.01           5.20            0.7400        0.000           1.200     0.0410
#
# ...

# %%
wine_reviews.sort_index(axis=0)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_reviews.reset_index(drop=True).head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...
